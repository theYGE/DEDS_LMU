# %%
#Data Extension 
import numpy as np
import pandas as pd
import random
pd.options.display.max_rows = 1000

# %%
adults = pd.read_csv('adult.csv')

# %%
adults.head()
# Out:
#    age  workclass  fnlwgt  ... hours-per-week  native-country income
# 0   25    Private  226802  ...             40   United-States  <=50K
# 1   38    Private   89814  ...             50   United-States  <=50K
# 2   28  Local-gov  336951  ...             40   United-States   >50K
# 3   44    Private  160323  ...             40   United-States   >50K
# 4   18          ?  103497  ...             30   United-States  <=50K
#
# [5 rows x 15 columns]

# %%
adults.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
adults.shape
# Out:
# (48842, 15)

# %%
sample = random.sample(range(20000, 70000), 48842)

# %%
adults['id-num'] = sample

# %%
adults.head()
# Out:
#    age  workclass  fnlwgt  ... native-country  income id-num
# 0   25    Private  226802  ...  United-States   <=50K  21757
# 1   38    Private   89814  ...  United-States   <=50K  25372
# 2   28  Local-gov  336951  ...  United-States    >50K  51650
# 3   44    Private  160323  ...  United-States    >50K  27130
# 4   18          ?  103497  ...  United-States   <=50K  67581
#
# [5 rows x 16 columns]

# %%
country_city = {"United-States": ["New York", "Los Angeles", "Miami"],
               "Cambodia": ["Phnom Penh","Battambang","Siem Reap"],
               "England": ["London","Birmingham","Cambridge"],
               "Puerto-Rico": ["San Juan","Bayamon","Carolina"],
               "Canada": ["Toronto","Montréal","Vancouver"],
               "Germany": ["Munich","Berlin","Hamburg"],
               "Outlying-US(Guam-USVI-etc)": ["Outlying-US(Guam-USVI-etc)"],
               "India": ["Mumbai","Delhi","Kolkata"],
               "Japan": ["Tokyo","Yokohama","Osaka"],
               "Greece": ["Athens","Thessaloniki","Patras"],
               "South": ["South"],
               "China": ["Shanghai","Beijing","Tianjin"],
               "Cuba": ["Havana","Santiago de Cuba","Camagüey"],
               "Iran": ["Tehran","Mashhad","Isfahan"],
               "Honduras": ["Tegucigalpa","San Pedro Sula","Choloma"],
               "Philippines": ["Manila","Quezon City","Davao City"],
               "Italy": ["Rome","Torino","Venice"],
               "Poland": ["Lublin","Bydgoszcz","Szczecin"],
               "Jamaica": ["Portmore","Kingston","May Pen"],
               "Vietnam": ["Da Nang","SBien Hoa","Can Tho"],
               "Mexico": ["Puebla","Guadalajara","Ecatepec"],
               "Portugal": ["Lisbon","Porto","Braga"],
               "Ireland": ["Dublin","Belfast","Cork"],
               "France": ["Paris","Toulouse","Marseille"],
               "Dominican-Republic": ["Santo Domingo","Santiago de los Caballero","Santo Domingo Oeste"],
               "Laos": ["Vientiane","Savannakhet","Pakxe"],
               "Ecuador": ["Guayaquil","Quito","Cuenca"],
               "Taiwan": ["New Taipei City","Kaohsiung City","Taichung City"],
               "Haiti": ["Port-au-Prince","Carrefour","Delmas"],
               "Columbia": ["Bogota","Medellin","Cali"],
               "Hungary": ["Budapest","Debrecen","Szeged"],
               "Guatemala": ["Ciudad de Guatemala","Villa Nueva","Mixco"],
               "Nicaragua": ["Managua","León","Masaya"],
               "Scotland": ["Glasgow","Edinburgh","Aberdeen"],
               "Thailand": ["Bangkok","Nonthaburi","Nakhon Ratchasima"],
               "Yugoslavia": ["Beograd","Zagreb","Sarajevo"],
               "El-Salvador": ["El-Salvador"],
               "Trinadad&Tobago": ["Trinadad&Tobago"],
               "Peru": ["Peru"],
               "Hong": ["Hong"],
               "?": ["?"],
               "Holand-Netherlands": ["Holand-Netherlands"]}

# %%
adults["hometown"] = adults["native-country"].map(lambda country: random.choice(country_city[country]))

# %%
# No explicit NaN
adults.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# id-num             0
# hometown           0
# dtype: int64

# %%
# Missing values are represented by ?
for column in adults:
  if '?' in adults[column].value_counts():
    print("Number of missing values for column " , column, ": ", adults[column].value_counts()['?'])
# Out:
# Number of missing values for column  workclass :  2799
# Number of missing values for column  occupation :  2809
# Number of missing values for column  native-country :  857
# Number of missing values for column  hometown :  857

# %%
# Filling in missing values for workclass with most frequent value
print(adults['workclass'].value_counts())
adults['workclass'].replace({"?":"Private"}, inplace = True)

# Filling in missing values for occupation with a random value from occupation
print(adults['occupation'].value_counts())
unique_occupations = list(adults['occupation'].unique())
if '?' in unique_occupations:
  unique_occupations.remove("?")
adults['occupation'] = adults['occupation'].apply(lambda x: random.choice(unique_occupations) if x == '?' else x)

# Filling in missing values for native-country with most frequent value
print(adults['native-country'].value_counts())
adults['native-country'].replace({"?":"United States"}, inplace = True)
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Nicaragua                        49
# Greece                           49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Thailand                         30
# Hong                             30
# Cambodia                         28
# Trinadad&Tobago                  27
# Yugoslavia                       23
# Laos                             23
# Outlying-US(Guam-USVI-etc)       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
# Checking if cities with ? are all from the US
set_of_countries_with_missing_cities = set()
for index, row in adults.iterrows():
  if row['hometown'] == '?':
    set_of_countries_with_missing_cities.add(row["native-country"])
print(set_of_countries_with_missing_cities)
# Out:
# {'United States'}

# %%
# Substitute missing city with a random city from the United States
adults["hometown"] = adults['hometown'].apply(lambda city: random.choice(country_city['United-States']) if city == '?' else city)

# %%
# Missing values are represented by ?
for column in adults:
  if '?' in adults[column].value_counts():
    print("Number of missing values for column " , column, ": ", adults[column].value_counts()['?'])

# %%
adults['income'].value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %%
# Changing the income brackets for income column
# Filled according to https://dqydj.com/average-median-top-household-income-percentiles/
income_brackets = ['<=50K', '50K-100K', '100K-150K', '150K+']
probabilities = [ 0.38, 0.29, 0.15, 0.18]
adults['income'] = adults['income'].apply(lambda x: np.random.choice(income_brackets, p = probabilities))

# %%
adults['income'].value_counts()
# Out:
# <=50K        18434
# 50K-100K     14282
# 150K+         8914
# 100K-150K     7212
# Name: income, dtype: int64

# %%
adults.shape
# Out:
# (48842, 17)

# %%
adults
# Out:
#        age     workclass  fnlwgt  ...     income  id-num     hometown
# 0       25       Private  226802  ...      150K+   21757        Miami
# 1       38       Private   89814  ...   50K-100K   25372     New York
# 2       28     Local-gov  336951  ...   50K-100K   51650        Miami
# 3       44       Private  160323  ...  100K-150K   27130        Miami
# 4       18       Private  103497  ...  100K-150K   67581        Miami
# ...    ...           ...     ...  ...        ...     ...          ...
# 48837   27       Private  257302  ...   50K-100K   51965        Miami
# 48838   40       Private  154374  ...  100K-150K   45460  Los Angeles
# 48839   58       Private  151910  ...   50K-100K   24013     New York
# 48840   22       Private  201490  ...   50K-100K   58040  Los Angeles
# 48841   52  Self-emp-inc  287927  ...      <=50K   58301  Los Angeles
#
# [48842 rows x 17 columns]

# %%
adults_sub1 = adults[["age","id-num","native-country","hometown","race","gender"]]
adults_sub1.to_csv("adults_sub1.csv")
adults_sub1
# Out:
#        age  id-num native-country     hometown   race  gender
# 0       25   21757  United-States        Miami  Black    Male
# 1       38   25372  United-States     New York  White    Male
# 2       28   51650  United-States        Miami  White    Male
# 3       44   27130  United-States        Miami  Black    Male
# 4       18   67581  United-States        Miami  White  Female
# ...    ...     ...            ...          ...    ...     ...
# 48837   27   51965  United-States        Miami  White  Female
# 48838   40   45460  United-States  Los Angeles  White    Male
# 48839   58   24013  United-States     New York  White  Female
# 48840   22   58040  United-States  Los Angeles  White    Male
# 48841   52   58301  United-States  Los Angeles  White  Female
#
# [48842 rows x 6 columns]

# %%
adults_sub1["age"] = adults_sub1['age'].apply(lambda age: str(int(age/10)) + "*")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
adults_sub1.to_csv("adults_sub1_final.csv")

# %%
adults_sub2 = adults.drop(["age","native-country","hometown","race","gender"],axis=1)
adults_sub2.to_csv("adults_sub2.csv")
adults_sub2
# Out:
#           workclass  fnlwgt     education  ...  hours-per-week     income id-num
# 0           Private  226802          11th  ...              40      150K+  21757
# 1           Private   89814       HS-grad  ...              50   50K-100K  25372
# 2         Local-gov  336951    Assoc-acdm  ...              40   50K-100K  51650
# 3           Private  160323  Some-college  ...              40  100K-150K  27130
# 4           Private  103497  Some-college  ...              30  100K-150K  67581
# ...             ...     ...           ...  ...             ...        ...    ...
# 48837       Private  257302    Assoc-acdm  ...              38   50K-100K  51965
# 48838       Private  154374       HS-grad  ...              40  100K-150K  45460
# 48839       Private  151910       HS-grad  ...              40   50K-100K  24013
# 48840       Private  201490       HS-grad  ...              20   50K-100K  58040
# 48841  Self-emp-inc  287927       HS-grad  ...              40      <=50K  58301
#
# [48842 rows x 12 columns]

# %%
adults_sub1.head()
# Out:
#   age  id-num native-country  hometown   race  gender
# 0  2*   21757  United-States     Miami  Black    Male
# 1  3*   25372  United-States  New York  White    Male
# 2  2*   51650  United-States     Miami  White    Male
# 3  4*   27130  United-States     Miami  Black    Male
# 4  1*   67581  United-States     Miami  White  Female

# %%
adults_sub2.head()
# Out:
#    workclass  fnlwgt     education  ...  hours-per-week     income id-num
# 0    Private  226802          11th  ...              40      150K+  21757
# 1    Private   89814       HS-grad  ...              50   50K-100K  25372
# 2  Local-gov  336951    Assoc-acdm  ...              40   50K-100K  51650
# 3    Private  160323  Some-college  ...              40  100K-150K  27130
# 4    Private  103497  Some-college  ...              30  100K-150K  67581
#
# [5 rows x 12 columns]

# %%
adults.to_csv("new_adults.csv")

# %% [markdown]
# # K-anonimity

# %%
adults_sub2.drop(columns = ["fnlwgt", "educational-num"], inplace = True)

# %%
adults_sub2.columns
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'capital-gain', 'capital-loss', 'hours-per-week',
#        'income', 'id-num'],
#       dtype='object')

# %%
for column in adults_sub2:
  print("Value counts for column ", column, " are: ")
  print(adults_sub2[column].value_counts(), '\n')
# Out:
# Value counts for column  workclass  are:
# Private             36705
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64
#
# Value counts for column  education  are:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64
#
# Value counts for column  marital-status  are:
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64
#
# Value counts for column  occupation  are:
# Prof-specialty       6366
# Craft-repair         6300
# Exec-managerial      6281
# Adm-clerical         5795
# Sales                5713
# Other-service        5129
# Machine-op-inspct    3222
# Transport-moving     2557
# Handlers-cleaners    2265
# Farming-fishing      1694
# Tech-support         1650
# Protective-serv      1193
# Priv-house-serv       468
# Armed-Forces          209
# Name: occupation, dtype: int64
#
# Value counts for column  relationship  are:
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: relationship, dtype: int64
#
# Value counts for column  capital-gain  are:
# 0        44807
# 15024      513
# 7688       410
# 7298       364
# 99999      244
# 3103       152
# 5178       146
# 5013       117
# 4386       108
# 8614        82
# 3325        81
# 2174        74
# 10520       64
# 4650        63
# 27828       58
# 4064        54
# 594         52
# 3137        51
# 20051       49
# 14084       49
# 3908        42
# 6849        42
# 13550       42
# 2829        42
# 1055        37
# 4787        35
# 3411        34
# 14344       34
# 3464        33
# 2597        31
# 2176        31
# 9386        31
# 2885        30
# 4101        29
# 2202        28
# 4865        25
# 2407        25
# 4416        24
# 1506        24
# 4508        23
# 3674        22
# 2354        21
# 2580        20
# 10605       19
# 2907        18
# 3942        18
# 5455        18
# 3781        16
# 6418        16
# 7430        15
# 2463        15
# 2105        15
# 6497        15
# 2635        14
# 2964        14
# 25236       14
# 1151        13
# 2653        11
# 3818        11
# 2977        11
# 3471        11
# 6514        10
# 1409        10
# 914         10
# 2290        10
# 15020       10
# 1797        10
# 2414        10
# 4934        10
# 1831         9
# 1471         9
# 1848         9
# 114          8
# 15831        8
# 10566        8
# 2346         8
# 3887         8
# 1086         8
# 3418         8
# 2329         7
# 3273         7
# 7443         7
# 5721         7
# 3456         6
# 34095        6
# 5556         6
# 25124        6
# 991          6
# 6767         6
# 1173         5
# 2036         5
# 2228         5
# 401          5
# 9562         5
# 2538         5
# 6723         5
# 2050         5
# 11678        4
# 2936         4
# 7896         4
# 4931         4
# 4687         4
# 2961         4
# 1455         4
# 1424         4
# 3432         4
# 2062         3
# 2993         3
# 2009         3
# 6360         3
# 41310        3
# 6097         2
# 5060         2
# 18481        2
# 1264         2
# 7978         2
# 7262         1
# 1731         1
# 2387         1
# 22040        1
# 6612         1
# 1111         1
# 1639         1
# Name: capital-gain, dtype: int64
#
# Value counts for column  capital-loss  are:
# 0       46560
# 1902      304
# 1977      253
# 1887      233
# 2415       72
# 1485       71
# 1848       67
# 1590       62
# 1602       62
# 1876       59
# 1740       58
# 1672       50
# 1741       44
# 1564       43
# 2258       39
# 1719       38
# 1980       36
# 2001       35
# 1408       35
# 1669       35
# 2002       33
# 1579       30
# 2051       29
# 1974       28
# 1721       28
# 2339       27
# 1504       26
# 2377       25
# 1628       24
# 1762       20
# 2444       20
# 2179       20
# 2205       19
# 2559       17
# 625        17
# 2057       16
# 2824       14
# 1573       12
# 2042       12
# 1651       11
# 1092       11
# 1617       11
# 2392       11
# 1340       11
# 1380       10
# 2174       10
# 1668        9
# 1594        9
# 1726        9
# 2246        8
# 2603        7
# 2129        7
# 2231        7
# 2206        6
# 880         6
# 1258        6
# 1825        5
# 3004        5
# 323         5
# 213         5
# 2149        5
# 2547        5
# 2472        4
# 2457        4
# 1816        4
# 3770        4
# 1138        4
# 653         4
# 2238        4
# 1411        4
# 4356        3
# 419         3
# 1944        3
# 2267        3
# 1510        3
# 1735        3
# 1429        3
# 1844        3
# 1648        3
# 3175        2
# 2163        2
# 2467        2
# 3683        2
# 2352        2
# 2754        2
# 2282        2
# 3900        2
# 810         2
# 1755        2
# 974         2
# 2080        1
# 2465        1
# 1911        1
# 155         1
# 1539        1
# 2489        1
# 2201        1
# 1421        1
# 1870        1
# Name: capital-loss, dtype: int64
#
# Value counts for column  hours-per-week  are:
# 40    22803
# 50     4246
# 45     2717
# 60     2177
# 35     1937
# 20     1862
# 30     1700
# 55     1051
# 25      958
# 48      770
# 38      714
# 15      623
# 70      437
# 10      425
# 32      423
# 65      355
# 24      354
# 42      338
# 36      336
# 44      310
# 16      303
# 12      247
# 37      242
# 43      227
# 8       218
# 80      210
# 52      205
# 56      141
# 28      140
# 99      137
# 18      129
# 46      129
# 72      107
# 75      105
# 5        95
# 6        92
# 4        84
# 47       82
# 84       72
# 39       63
# 22       62
# 54       62
# 33       61
# 41       59
# 3        59
# 14       55
# 2        53
# 34       48
# 21       46
# 7        45
# 27       43
# 17       42
# 90       42
# 26       40
# 23       40
# 53       39
# 49       39
# 58       38
# 13       28
# 1        27
# 9        27
# 62       23
# 66       23
# 64       22
# 11       20
# 51       20
# 19       19
# 57       19
# 85       17
# 68       16
# 63       15
# 29       15
# 98       14
# 78       13
# 31       12
# 96        9
# 77        9
# 59        7
# 67        6
# 76        4
# 61        4
# 73        4
# 86        4
# 88        4
# 74        3
# 92        3
# 81        3
# 91        3
# 89        3
# 97        2
# 95        2
# 69        1
# 94        1
# 79        1
# 82        1
# 87        1
# Name: hours-per-week, dtype: int64
#
# Value counts for column  income  are:
# <=50K        18434
# 50K-100K     14282
# 150K+         8914
# 100K-150K     7212
# Name: income, dtype: int64
#
# Value counts for column  id-num  are:
# 67583    1
# 23873    1
# 50514    1
# 56657    1
# 54608    1
#         ..
# 51852    1
# 62091    1
# 64138    1
# 57993    1
# 65536    1
# Name: id-num, Length: 48842, dtype: int64

# %%
adults_sub2.groupby(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week',
       'income']).size().reset_index(name='counts')
# Out:
#          workclass     education  ...     income counts
# 0      Federal-gov          10th  ...      150K+      1
# 1      Federal-gov          10th  ...   50K-100K      1
# 2      Federal-gov          10th  ...   50K-100K      1
# 3      Federal-gov          10th  ...  100K-150K      1
# 4      Federal-gov          10th  ...      150K+      1
# ...            ...           ...  ...        ...    ...
# 23413  Without-pay       HS-grad  ...      <=50K      1
# 23414  Without-pay       HS-grad  ...      <=50K      1
# 23415  Without-pay  Some-college  ...      <=50K      1
# 23416  Without-pay  Some-college  ...   50K-100K      1
# 23417  Without-pay  Some-college  ...      <=50K      1
#
# [23418 rows x 8 columns]

# %%
adults_sub2.groupby(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week'])["income"].unique()
# Out:
# workclass    education     marital-status         occupation         relationship   hours-per-week
# Federal-gov  10th          Divorced               Adm-clerical       Unmarried      50                              [150K+]
#                                                   Craft-repair       Unmarried      40                           [50K-100K]
#                                                   Other-service      Not-in-family  37                           [50K-100K]
#                            Married-civ-spouse     Adm-clerical       Husband        40                   [150K+, 100K-150K]
#                                                   Craft-repair       Husband        40                [50K-100K, 100K-150K]
#                                                                                                               ...
# Without-pay  HS-grad       Never-married          Handlers-cleaners  Own-child      40                              [<=50K]
#                                                   Other-service      Own-child      10                              [<=50K]
#              Some-college  Married-civ-spouse     Adm-clerical       Wife           16                              [<=50K]
#                                                   Farming-fishing    Own-child      65                           [50K-100K]
#                            Married-spouse-absent  Farming-fishing    Unmarried      25                              [<=50K]
# Name: income, Length: 15900, dtype: object

# %%
adults_sub2.groupby(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week'])["income"].value_counts()
# As we can see, there are already some groups where the individual is identified exactly,
# Out:
# workclass    education     marital-status         occupation         relationship   hours-per-week  income
# Federal-gov  10th          Divorced               Adm-clerical       Unmarried      50              150K+        1
#                                                   Craft-repair       Unmarried      40              50K-100K     1
#                                                   Other-service      Not-in-family  37              50K-100K     1
#                            Married-civ-spouse     Adm-clerical       Husband        40              100K-150K    1
#                                                                                                     150K+        1
#                                                                                                                 ..
# Without-pay  HS-grad       Never-married          Handlers-cleaners  Own-child      40              <=50K        1
#                                                   Other-service      Own-child      10              <=50K        1
#              Some-college  Married-civ-spouse     Adm-clerical       Wife           16              <=50K        1
#                                                   Farming-fishing    Own-child      65              50K-100K     1
#                            Married-spouse-absent  Farming-fishing    Unmarried      25              <=50K        1
# Name: income, Length: 23418, dtype: int64

# %%
# Version 1
# def generalize_work_hours(hours):
#   if hours < 20:
#     return '<20'
#   elif hours < 40:
#     return '20-40'
#   elif hours < 60:
#     return '40-60'
#   else:
#     return '>60'

# %%
def generalize_work_hours(hours):
  if hours < 40:
    return '<40'
  elif hours == 40:
    return "40"
  else:
    return '>40'

# %%
adults_sub2['hours-per-week'] = adults_sub2['hours-per-week'].apply(generalize_work_hours)

# %%
# adults_sub2["occupation"].value_counts()

# %%
def generalize_occupation(occupation):
  if occupation in ("Prof-specialty", "Exec-managerial", "Adm-clerical", "Sales"):
    return "Business Industry"
  else:
    return "Non-Business Industry"

# %%
# V1 
# def generalize_occupation(occupation):
#   if occupation in ("Craft-repair", "Handlers-cleaners", "Protective-serv", "Tech-support", "Machine-op-inspct", "Transport-moving"):
#     return "Service Industry"
#   elif occupation in ("Prof-specialty", "Exec-managerial", "Adm-clerical", "Sales"):
#     return "Business Industry"
#   else:
#     return "Other Services/Industry"

# %%
adults_sub2["occupation"] = adults_sub2["occupation"].apply(generalize_occupation)

# %%
def generalize_relationship(status):
  if status in ("Husband", "Wife"):
    return "Spouse"
  else:
    return "Non-Spouse"

# %%
adults_sub2['relationship'] = adults_sub2['relationship'].apply(generalize_relationship)

# %%
def generalize_workclass(workclass):
  if workclass == "Private":
    return 'Private'
  elif workclass in ("Local-gov", "State-gov", "Federal-gov"):
    return 'Government'
  else:
    return "Self-Employed or No Pay"

# %%
adults_sub2['workclass'] = adults_sub2['workclass'].apply(generalize_workclass)

# %%
# adults_sub2["education"].value_counts()

# %%
def generalize_edication(education):
  if education in ("HS-grad", "1st-4th", "5th-6th", "12th", "9th", "7th-8th", "10th", "11th", "Preschool"):
    return "HS-Grad or lower"
  else:
    return "Higher Education"
  # elif education in ("Assoc-voc", "Assoc-acdm"):
  #   return "Associate"
  # else:
  #   return education

# %%
# Version 1
# def generalize_edication(education):
#   if education in ("1st-4th", "5th-6th", "12th", "9th", "7th-8th", "10th", "11th", "Preschool"):
#     return "No HS Grad"
#   elif education in ("Assoc-voc", "Assoc-acdm"):
#     return "Associate"
#   else:
#     return education

# %%
adults_sub2['education'] = adults_sub2['education'].apply(generalize_edication)

# %%
def generalize_marital_status(status):
  if status in ("Married-civ-spouse", "Separated", "Married-spouse-absent", "Married-AF-spouse"):
    return "Married"
  else:
    return "Single"

# %%
adults_sub2['marital-status'] = adults_sub2['marital-status'].apply(generalize_marital_status)

# %%
# def generalize_capital_gain(gain):
#   if gain < 500:
#     return "< 500"
#   elif gain < 1500:
#     return "500 - 1500"
#   elif gain < 3500:
#     return "1500 - 3500"
#   elif gain < 5000:
#     return "3500 - 5000"
#   elif gain < 10000:
#     return "5000 - 10000"
#   elif gain < 20000:
#     return "10000 - 20000"
#   else:
#     return '>20000'

# %%
# adults_sub2['capital-gain'] = adults_sub2['capital-gain'].apply(generalize_capital_gain)

# %%
# def generalize_capital_loss(loss):
#   if loss < 500:
#     return "<500"
#   elif loss < 1500:
#     return "500 - 1500"
#   elif loss < 3000:
#     return "1500 - 3000"
#   elif loss < 7000:
#     return "3000 - 70000"
#   if loss < 10000:
#     return "7000 - 10000"
#   elif loss < 20000:
#     return "10000 - 20000"
#   else:
#     return '>20000'

# %%
# adults_sub2['capital-loss'] = adults_sub2['capital-loss'].apply(generalize_capital_loss)

# %%
for column in adults_sub2:
  print("Value counts for column ", column, " are: ")
  print(adults_sub2[column].value_counts(), '\n')
# Out:
# Value counts for column  workclass  are:
# Private                    36705
# Government                  6549
# Self-Employed or No Pay     5588
# Name: workclass, dtype: int64
#
# Value counts for column  education  are:
# Higher Education    26650
# HS-Grad or lower    22192
# Name: education, dtype: int64
#
# Value counts for column  marital-status  are:
# Married    24574
# Single     24268
# Name: marital-status, dtype: int64
#
# Value counts for column  occupation  are:
# Non-Business Industry    24687
# Business Industry        24155
# Name: occupation, dtype: int64
#
# Value counts for column  relationship  are:
# Non-Spouse    26795
# Spouse        22047
# Name: relationship, dtype: int64
#
# Value counts for column  capital-gain  are:
# 0        44807
# 15024      513
# 7688       410
# 7298       364
# 99999      244
# 3103       152
# 5178       146
# 5013       117
# 4386       108
# 8614        82
# 3325        81
# 2174        74
# 10520       64
# 4650        63
# 27828       58
# 4064        54
# 594         52
# 3137        51
# 20051       49
# 14084       49
# 3908        42
# 6849        42
# 13550       42
# 2829        42
# 1055        37
# 4787        35
# 3411        34
# 14344       34
# 3464        33
# 2597        31
# 2176        31
# 9386        31
# 2885        30
# 4101        29
# 2202        28
# 4865        25
# 2407        25
# 4416        24
# 1506        24
# 4508        23
# 3674        22
# 2354        21
# 2580        20
# 10605       19
# 2907        18
# 3942        18
# 5455        18
# 3781        16
# 6418        16
# 7430        15
# 2463        15
# 2105        15
# 6497        15
# 2635        14
# 2964        14
# 25236       14
# 1151        13
# 2653        11
# 3818        11
# 2977        11
# 3471        11
# 6514        10
# 1409        10
# 914         10
# 2290        10
# 15020       10
# 1797        10
# 2414        10
# 4934        10
# 1831         9
# 1471         9
# 1848         9
# 114          8
# 15831        8
# 10566        8
# 2346         8
# 3887         8
# 1086         8
# 3418         8
# 2329         7
# 3273         7
# 7443         7
# 5721         7
# 3456         6
# 34095        6
# 5556         6
# 25124        6
# 991          6
# 6767         6
# 1173         5
# 2036         5
# 2228         5
# 401          5
# 9562         5
# 2538         5
# 6723         5
# 2050         5
# 11678        4
# 2936         4
# 7896         4
# 4931         4
# 4687         4
# 2961         4
# 1455         4
# 1424         4
# 3432         4
# 2062         3
# 2993         3
# 2009         3
# 6360         3
# 41310        3
# 6097         2
# 5060         2
# 18481        2
# 1264         2
# 7978         2
# 7262         1
# 1731         1
# 2387         1
# 22040        1
# 6612         1
# 1111         1
# 1639         1
# Name: capital-gain, dtype: int64
#
# Value counts for column  capital-loss  are:
# 0       46560
# 1902      304
# 1977      253
# 1887      233
# 2415       72
# 1485       71
# 1848       67
# 1590       62
# 1602       62
# 1876       59
# 1740       58
# 1672       50
# 1741       44
# 1564       43
# 2258       39
# 1719       38
# 1980       36
# 2001       35
# 1408       35
# 1669       35
# 2002       33
# 1579       30
# 2051       29
# 1974       28
# 1721       28
# 2339       27
# 1504       26
# 2377       25
# 1628       24
# 1762       20
# 2444       20
# 2179       20
# 2205       19
# 2559       17
# 625        17
# 2057       16
# 2824       14
# 1573       12
# 2042       12
# 1651       11
# 1092       11
# 1617       11
# 2392       11
# 1340       11
# 1380       10
# 2174       10
# 1668        9
# 1594        9
# 1726        9
# 2246        8
# 2603        7
# 2129        7
# 2231        7
# 2206        6
# 880         6
# 1258        6
# 1825        5
# 3004        5
# 323         5
# 213         5
# 2149        5
# 2547        5
# 2472        4
# 2457        4
# 1816        4
# 3770        4
# 1138        4
# 653         4
# 2238        4
# 1411        4
# 4356        3
# 419         3
# 1944        3
# 2267        3
# 1510        3
# 1735        3
# 1429        3
# 1844        3
# 1648        3
# 3175        2
# 2163        2
# 2467        2
# 3683        2
# 2352        2
# 2754        2
# 2282        2
# 3900        2
# 810         2
# 1755        2
# 974         2
# 2080        1
# 2465        1
# 1911        1
# 155         1
# 1539        1
# 2489        1
# 2201        1
# 1421        1
# 1870        1
# Name: capital-loss, dtype: int64
#
# Value counts for column  hours-per-week  are:
# 40     22803
# >40    14352
# <40    11687
# Name: hours-per-week, dtype: int64
#
# Value counts for column  income  are:
# <=50K        18434
# 50K-100K     14282
# 150K+         8914
# 100K-150K     7212
# Name: income, dtype: int64
#
# Value counts for column  id-num  are:
# 67583    1
# 23873    1
# 50514    1
# 56657    1
# 54608    1
#         ..
# 51852    1
# 62091    1
# 64138    1
# 57993    1
# 65536    1
# Name: id-num, Length: 48842, dtype: int64

# %%
adults_sub2.columns
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'capital-gain', 'capital-loss', 'hours-per-week',
#        'income', 'id-num'],
#       dtype='object')

# %%
adults_sub2.groupby(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'capital-gain', 'capital-loss', 'hours-per-week',
       'income']).size()
# Out:
# workclass                education         marital-status  occupation             relationship  capital-gain  capital-loss  hours-per-week  income
# Government               HS-Grad or lower  Married         Business Industry      Non-Spouse    0             0             40              100K-150K     4
#                                                                                                                                             150K+         2
#                                                                                                                                             50K-100K      7
#                                                                                                                                             <=50K        14
#                                                                                                                             <40             100K-150K     1
#                                                                                                                                                          ..
# Self-Employed or No Pay  Higher Education  Single          Non-Business Industry  Non-Spouse    10520         0             >40             <=50K         2
#                                                                                                 15831         0             <40             <=50K         1
#                                                                                                 27828         0             <40             50K-100K      1
#                                                                                                                             >40             50K-100K      2
#                                                                                                                                             <=50K         1
# Length: 3808, dtype: int64

# %%
# existing capital gain/loss values are insufficient to reach k-anonimity
# We need to improve generalization

# %%
def improved_generalize_capital_gain(gain):
  # if gain == 0:
  #   return 0
  if gain < 50:
    return "< 50"
  elif gain < 150:
    return "50 - 150"
  elif gain < 250:
    return "150 - 250"
  elif gain < 350:
    return "250 - 350"
  elif gain < 500:
    return "350 - 500"
  elif gain < 1500:
    return "500 - 1500"
  elif gain < 3500:
    return "1500 - 3500"
  elif gain < 5000:
    return "3500 - 5000"
  elif gain < 10000:
    return "5000 - 10000"
  elif gain < 20000:
    return "10000 - 20000"
  else:
    return '>20000'

# %%
adults_sub2['capital-gain'] = adults_sub2['capital-gain'].apply(improved_generalize_capital_gain)

# %%
def improved_generalize_capital_loss(loss):
  # if loss == 0:
  #   return 0
  if loss < 50:
    return "< 50"
  elif loss < 150:
    return "50 - 150"
  elif loss < 250:
    return "150 - 250"
  elif loss < 350:
    return "250 - 350"
  elif loss < 500:
    return "350 - 500"
  if loss < 500:
    return "<500"
  elif loss < 1500:
    return "500 - 1500"
  elif loss < 3000:
    return "1500 - 3000"
  elif loss < 7000:
    return "3000 - 70000"
  if loss < 10000:
    return "7000 - 10000"
  elif loss < 20000:
    return "10000 - 20000"
  else:
    return '>20000'

# %%
adults_sub2['capital-loss'] = adults_sub2['capital-loss'].apply(improved_generalize_capital_loss)

# %%
for column in adults_sub2:
  print("Value counts for column ", column, " are: ")
  print(adults_sub2[column].value_counts(), '\n')
# Out:
# Value counts for column  workclass  are:
# Private                    36705
# Government                  6549
# Self-Employed or No Pay     5588
# Name: workclass, dtype: int64
#
# Value counts for column  education  are:
# Higher Education    26650
# HS-Grad or lower    22192
# Name: education, dtype: int64
#
# Value counts for column  marital-status  are:
# Married    24574
# Single     24268
# Name: marital-status, dtype: int64
#
# Value counts for column  occupation  are:
# Non-Business Industry    24687
# Business Industry        24155
# Name: occupation, dtype: int64
#
# Value counts for column  relationship  are:
# Non-Spouse    26795
# Spouse        22047
# Name: relationship, dtype: int64
#
# Value counts for column  capital-gain  are:
# < 50             44807
# 5000 - 10000      1317
# 1500 - 3500        914
# 10000 - 20000      753
# 3500 - 5000        496
# >20000             381
# 500 - 1500         161
# 50 - 150             8
# 350 - 500            5
# Name: capital-gain, dtype: int64
#
# Value counts for column  capital-loss  are:
# < 50            46560
# 1500 - 3000      2063
# 500 - 1500        187
# 3000 - 70000       18
# 150 - 250           6
# 250 - 350           5
# 350 - 500           3
# Name: capital-loss, dtype: int64
#
# Value counts for column  hours-per-week  are:
# 40     22803
# >40    14352
# <40    11687
# Name: hours-per-week, dtype: int64
#
# Value counts for column  income  are:
# <=50K        18434
# 50K-100K     14282
# 150K+         8914
# 100K-150K     7212
# Name: income, dtype: int64
#
# Value counts for column  id-num  are:
# 67583    1
# 23873    1
# 50514    1
# 56657    1
# 54608    1
#         ..
# 51852    1
# 62091    1
# 64138    1
# 57993    1
# 65536    1
# Name: id-num, Length: 48842, dtype: int64

# %%
adults_sub2.groupby(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'capital-gain', 'capital-loss', 'hours-per-week',
       'income']).size()
# Out:
# workclass                education         marital-status  occupation             relationship  capital-gain  capital-loss  hours-per-week  income
# Government               HS-Grad or lower  Married         Business Industry      Non-Spouse    3500 - 5000   < 50          <40             50K-100K      1
#                                                                                                 500 - 1500    < 50          40              100K-150K     1
#                                                                                                 5000 - 10000  < 50          40              100K-150K     1
#                                                                                                                             <40             <=50K         1
#                                                                                                 < 50          1500 - 3000   40              <=50K         1
#                                                                                                                                                          ..
# Self-Employed or No Pay  Higher Education  Single          Non-Business Industry  Non-Spouse    < 50          < 50          >40             50K-100K     22
#                                                                                                                                             <=50K        36
#                                                                                                 >20000        < 50          <40             50K-100K      1
#                                                                                                                             >40             50K-100K      2
#                                                                                                                                             <=50K         1
# Length: 1839, dtype: int64

# %%
# Actually we need to drop capital loss/gain as 0 there represent 99%

# %%
adults_sub2.drop(columns = ["capital-loss", "capital-gain"], inplace = True)

# %%
# adults_sub2 = adults_sub2.reset_index()
# adults_sub2.drop(columns="index", inplace=True)
# adults_sub2.value_counts()

# %%
grouped_df = adults_sub2.groupby(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week',
       'income']).size().reset_index(name='counts')

# %%
grouped_df.sort_values("counts", ascending=True)
# Out:
#                    workclass         education  ...     income counts
# 289  Self-Employed or No Pay  HS-Grad or lower  ...      150K+      1
# 380  Self-Employed or No Pay  Higher Education  ...      150K+      1
# 383  Self-Employed or No Pay  Higher Education  ...  100K-150K      1
# 96                Government  Higher Education  ...  100K-150K      1
# 28                Government  HS-Grad or lower  ...  100K-150K      1
# 25                Government  HS-Grad or lower  ...      150K+      1
# 379  Self-Employed or No Pay  Higher Education  ...  100K-150K      1
# 356  Self-Employed or No Pay  Higher Education  ...  100K-150K      1
# 291  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K      1
# 4                 Government  HS-Grad or lower  ...  100K-150K      1
# 377  Self-Employed or No Pay  Higher Education  ...   50K-100K      2
# 97                Government  Higher Education  ...      150K+      2
# 288  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K      2
# 285  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K      2
# 29                Government  HS-Grad or lower  ...      150K+      2
# 312  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K      2
# 310  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K      2
# 305  Self-Employed or No Pay  HS-Grad or lower  ...      150K+      2
# 376  Self-Employed or No Pay  Higher Education  ...  100K-150K      2
# 282  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K      2
# 283  Self-Employed or No Pay  HS-Grad or lower  ...      150K+      2
# 1                 Government  HS-Grad or lower  ...      150K+      2
# 308  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K      2
# 352  Self-Employed or No Pay  Higher Education  ...  100K-150K      2
# 284  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K      3
# 24                Government  HS-Grad or lower  ...  100K-150K      3
# 52                Government  HS-Grad or lower  ...  100K-150K      3
# 98                Government  Higher Education  ...   50K-100K      3
# 100               Government  Higher Education  ...  100K-150K      3
# 16                Government  HS-Grad or lower  ...  100K-150K      3
# 286  Self-Employed or No Pay  HS-Grad or lower  ...      150K+      3
# 5                 Government  HS-Grad or lower  ...      150K+      3
# 378  Self-Employed or No Pay  Higher Education  ...      <=50K      4
# 384  Self-Employed or No Pay  Higher Education  ...      150K+      4
# 13                Government  HS-Grad or lower  ...      150K+      4
# 92                Government  Higher Education  ...  100K-150K      4
# 360  Self-Employed or No Pay  Higher Education  ...  100K-150K      4
# 381  Self-Employed or No Pay  Higher Education  ...   50K-100K      4
# 358  Self-Employed or No Pay  Higher Education  ...   50K-100K      4
# 309  Self-Employed or No Pay  HS-Grad or lower  ...      150K+      4
# 290  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K      5
# 64                Government  HS-Grad or lower  ...  100K-150K      5
# 76                Government  Higher Education  ...  100K-150K      5
# 332  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K      5
# 306  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K      5
# 31                Government  HS-Grad or lower  ...      <=50K      5
# 147                  Private  HS-Grad or lower  ...      150K+      5
# 353  Self-Employed or No Pay  Higher Education  ...      150K+      5
# 26                Government  HS-Grad or lower  ...   50K-100K      5
# 99                Government  Higher Education  ...      <=50K      5
# 7                 Government  HS-Grad or lower  ...      <=50K      5
# 101               Government  Higher Education  ...   50K-100K      5
# 287  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K      5
# 355  Self-Employed or No Pay  Higher Education  ...      <=50K      6
# 357  Self-Employed or No Pay  Higher Education  ...      150K+      6
# 359  Self-Employed or No Pay  Higher Education  ...      <=50K      6
# 382  Self-Employed or No Pay  Higher Education  ...      <=50K      6
# 386  Self-Employed or No Pay  Higher Education  ...      <=50K      6
# 385  Self-Employed or No Pay  Higher Education  ...   50K-100K      6
# 73                Government  Higher Education  ...      150K+      6
# 94                Government  Higher Education  ...   50K-100K      6
# 78                Government  Higher Education  ...   50K-100K      6
# 72                Government  Higher Education  ...  100K-150K      6
# 0                 Government  HS-Grad or lower  ...  100K-150K      6
# 20                Government  HS-Grad or lower  ...  100K-150K      6
# 313  Self-Employed or No Pay  HS-Grad or lower  ...      150K+      6
# 311  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K      6
# 304  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K      7
# 2                 Government  HS-Grad or lower  ...   50K-100K      7
# 54                Government  HS-Grad or lower  ...   50K-100K      7
# 27                Government  HS-Grad or lower  ...      <=50K      7
# 314  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K      7
# 12                Government  HS-Grad or lower  ...  100K-150K      7
# 77                Government  Higher Education  ...      150K+      7
# 53                Government  HS-Grad or lower  ...      150K+      8
# 17                Government  HS-Grad or lower  ...      150K+      8
# 243                  Private  Higher Education  ...      150K+      8
# 361  Self-Employed or No Pay  Higher Education  ...      150K+      8
# 30                Government  HS-Grad or lower  ...   50K-100K      8
# 6                 Government  HS-Grad or lower  ...   50K-100K      8
# 354  Self-Employed or No Pay  Higher Education  ...   50K-100K      8
# 242                  Private  Higher Education  ...  100K-150K      8
# 95                Government  Higher Education  ...      <=50K      8
# 75                Government  Higher Education  ...      <=50K      8
# 14                Government  HS-Grad or lower  ...   50K-100K      9
# 337  Self-Employed or No Pay  HS-Grad or lower  ...      150K+      9
# 21                Government  HS-Grad or lower  ...      150K+      9
# 93                Government  Higher Education  ...      150K+      9
# 106               Government  Higher Education  ...  100K-150K      9
# 307  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K      9
# 328  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K      9
# 333  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     10
# 362  Self-Employed or No Pay  Higher Education  ...   50K-100K     10
# 74                Government  Higher Education  ...   50K-100K     10
# 214                  Private  Higher Education  ...  100K-150K     11
# 65                Government  HS-Grad or lower  ...      150K+     11
# 415  Self-Employed or No Pay  Higher Education  ...  100K-150K     11
# 146                  Private  HS-Grad or lower  ...  100K-150K     11
# 329  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     11
# 22                Government  HS-Grad or lower  ...   50K-100K     11
# 107               Government  Higher Education  ...      150K+     12
# 411  Self-Employed or No Pay  Higher Education  ...  100K-150K     12
# 315  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K     12
# 36                Government  HS-Grad or lower  ...  100K-150K     13
# 149                  Private  HS-Grad or lower  ...      <=50K     13
# 363  Self-Employed or No Pay  Higher Education  ...      <=50K     13
# 130               Government  Higher Education  ...  100K-150K     14
# 334  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K     14
# 69                Government  Higher Education  ...      150K+     14
# 3                 Government  HS-Grad or lower  ...      <=50K     15
# 40                Government  HS-Grad or lower  ...  100K-150K     15
# 68                Government  Higher Education  ...  100K-150K     15
# 79                Government  Higher Education  ...      <=50K     15
# 18                Government  HS-Grad or lower  ...   50K-100K     16
# 134               Government  Higher Education  ...  100K-150K     16
# 142                  Private  HS-Grad or lower  ...  100K-150K     16
# 239                  Private  Higher Education  ...      150K+     16
# 345  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     16
# 330  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K     16
# 391  Self-Employed or No Pay  Higher Education  ...  100K-150K     16
# 297  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     16
# 37                Government  HS-Grad or lower  ...      150K+     16
# 108               Government  Higher Education  ...   50K-100K     16
# 238                  Private  Higher Education  ...  100K-150K     16
# 66                Government  HS-Grad or lower  ...   50K-100K     17
# 23                Government  HS-Grad or lower  ...      <=50K     17
# 170                  Private  HS-Grad or lower  ...  100K-150K     18
# 215                  Private  Higher Education  ...      150K+     18
# 340  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K     18
# 234                  Private  Higher Education  ...  100K-150K     18
# 109               Government  Higher Education  ...      <=50K     18
# 419  Self-Employed or No Pay  Higher Education  ...  100K-150K     18
# 55                Government  HS-Grad or lower  ...      <=50K     18
# 392  Self-Employed or No Pay  Higher Education  ...      150K+     19
# 60                Government  HS-Grad or lower  ...  100K-150K     20
# 19                Government  HS-Grad or lower  ...      <=50K     20
# 143                  Private  HS-Grad or lower  ...      150K+     21
# 399  Self-Employed or No Pay  Higher Education  ...  100K-150K     21
# 412  Self-Employed or No Pay  Higher Education  ...      150K+     21
# 41                Government  HS-Grad or lower  ...      150K+     21
# 39                Government  HS-Grad or lower  ...      <=50K     21
# 403  Self-Employed or No Pay  Higher Education  ...  100K-150K     21
# 244                  Private  Higher Education  ...   50K-100K     21
# 15                Government  HS-Grad or lower  ...      <=50K     21
# 420  Self-Employed or No Pay  Higher Education  ...      150K+     21
# 344  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K     21
# 336  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K     22
# 416  Self-Employed or No Pay  Higher Education  ...      150K+     22
# 38                Government  HS-Grad or lower  ...   50K-100K     22
# 70                Government  Higher Education  ...   50K-100K     23
# 400  Self-Employed or No Pay  Higher Education  ...      150K+     23
# 49                Government  HS-Grad or lower  ...      150K+     23
# 388  Self-Employed or No Pay  Higher Education  ...      150K+     23
# 48                Government  HS-Grad or lower  ...  100K-150K     24
# 42                Government  HS-Grad or lower  ...   50K-100K     24
# 240                  Private  Higher Education  ...   50K-100K     24
# 219                  Private  Higher Education  ...      150K+     24
# 218                  Private  Higher Education  ...  100K-150K     24
# 292  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K     25
# 387  Self-Employed or No Pay  Higher Education  ...  100K-150K     25
# 138                  Private  HS-Grad or lower  ...  100K-150K     25
# 148                  Private  HS-Grad or lower  ...   50K-100K     25
# 331  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K     26
# 111               Government  Higher Education  ...      150K+     26
# 8                 Government  HS-Grad or lower  ...  100K-150K     26
# 341  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     26
# 67                Government  HS-Grad or lower  ...      <=50K     26
# 126               Government  Higher Education  ...  100K-150K     27
# 241                  Private  Higher Education  ...      <=50K     27
# 135               Government  Higher Education  ...      150K+     27
# 320  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K     27
# 393  Self-Employed or No Pay  Higher Education  ...   50K-100K     28
# 139                  Private  HS-Grad or lower  ...      150K+     29
# 421  Self-Employed or No Pay  Higher Education  ...   50K-100K     29
# 296  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K     29
# 136               Government  Higher Education  ...   50K-100K     29
# 50                Government  HS-Grad or lower  ...   50K-100K     29
# 418  Self-Employed or No Pay  Higher Education  ...      <=50K     30
# 245                  Private  Higher Education  ...      <=50K     30
# 210                  Private  Higher Education  ...  100K-150K     30
# 131               Government  Higher Education  ...      150K+     30
# 61                Government  HS-Grad or lower  ...      150K+     30
# 404  Self-Employed or No Pay  Higher Education  ...      150K+     30
# 348  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K     30
# 220                  Private  Higher Education  ...   50K-100K     31
# 338  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K     31
# 335  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K     31
# 293  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     32
# 9                 Government  HS-Grad or lower  ...      150K+     32
# 110               Government  Higher Education  ...  100K-150K     32
# 171                  Private  HS-Grad or lower  ...      150K+     32
# 417  Self-Employed or No Pay  Higher Education  ...   50K-100K     32
# 413  Self-Employed or No Pay  Higher Education  ...   50K-100K     32
# 44                Government  HS-Grad or lower  ...  100K-150K     33
# 298  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K     34
# 137               Government  Higher Education  ...      <=50K     34
# 235                  Private  Higher Education  ...      150K+     34
# 349  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     34
# 394  Self-Employed or No Pay  Higher Education  ...      <=50K     35
# 144                  Private  HS-Grad or lower  ...   50K-100K     35
# 339  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K     35
# 71                Government  Higher Education  ...      <=50K     35
# 414  Self-Employed or No Pay  Higher Education  ...      <=50K     35
# 166                  Private  HS-Grad or lower  ...  100K-150K     35
# 133               Government  Higher Education  ...      <=50K     36
# 299  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K     36
# 342  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K     37
# 221                  Private  Higher Education  ...      <=50K     37
# 216                  Private  Higher Education  ...   50K-100K     38
# 217                  Private  Higher Education  ...      <=50K     38
# 321  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     39
# 63                Government  HS-Grad or lower  ...      <=50K     39
# 167                  Private  HS-Grad or lower  ...      150K+     39
# 172                  Private  HS-Grad or lower  ...   50K-100K     39
# 43                Government  HS-Grad or lower  ...      <=50K     39
# 236                  Private  Higher Education  ...   50K-100K     40
# 316  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K     40
# 368  Self-Employed or No Pay  Higher Education  ...  100K-150K     40
# 301  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     41
# 350  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K     41
# 422  Self-Employed or No Pay  Higher Education  ...      <=50K     41
# 85                Government  Higher Education  ...      150K+     41
# 132               Government  Higher Education  ...   50K-100K     43
# 346  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K     43
# 389  Self-Employed or No Pay  Higher Education  ...   50K-100K     43
# 145                  Private  HS-Grad or lower  ...      <=50K     45
# 140                  Private  HS-Grad or lower  ...   50K-100K     45
# 102               Government  Higher Education  ...  100K-150K     46
# 395  Self-Employed or No Pay  Higher Education  ...  100K-150K     46
# 62                Government  HS-Grad or lower  ...   50K-100K     47
# 401  Self-Employed or No Pay  Higher Education  ...   50K-100K     47
# 294  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K     47
# 56                Government  HS-Grad or lower  ...  100K-150K     47
# 84                Government  Higher Education  ...  100K-150K     49
# 10                Government  HS-Grad or lower  ...   50K-100K     49
# 405  Self-Employed or No Pay  Higher Education  ...   50K-100K     50
# 173                  Private  HS-Grad or lower  ...      <=50K     50
# 154                  Private  HS-Grad or lower  ...  100K-150K     50
# 211                  Private  Higher Education  ...      150K+     51
# 317  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     52
# 364  Self-Employed or No Pay  Higher Education  ...  100K-150K     52
# 45                Government  HS-Grad or lower  ...      150K+     53
# 322  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K     54
# 112               Government  Higher Education  ...   50K-100K     54
# 127               Government  Higher Education  ...      150K+     54
# 343  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K     55
# 46                Government  HS-Grad or lower  ...   50K-100K     55
# 402  Self-Employed or No Pay  Higher Education  ...      <=50K     55
# 237                  Private  Higher Education  ...      <=50K     55
# 406  Self-Employed or No Pay  Higher Education  ...      <=50K     55
# 57                Government  HS-Grad or lower  ...      150K+     56
# 155                  Private  HS-Grad or lower  ...      150K+     56
# 300  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K     56
# 51                Government  HS-Grad or lower  ...      <=50K     57
# 408  Self-Employed or No Pay  Higher Education  ...      150K+     58
# 390  Self-Employed or No Pay  Higher Education  ...      <=50K     58
# 295  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K     60
# 351  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K     60
# 122               Government  Higher Education  ...  100K-150K     61
# 407  Self-Employed or No Pay  Higher Education  ...  100K-150K     61
# 212                  Private  Higher Education  ...   50K-100K     61
# 347  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K     62
# 365  Self-Employed or No Pay  Higher Education  ...      150K+     62
# 369  Self-Employed or No Pay  Higher Education  ...      150K+     63
# 11                Government  HS-Grad or lower  ...      <=50K     64
# 370  Self-Employed or No Pay  Higher Education  ...   50K-100K     66
# 250                  Private  Higher Education  ...  100K-150K     67
# 396  Self-Employed or No Pay  Higher Education  ...      150K+     67
# 168                  Private  HS-Grad or lower  ...   50K-100K     69
# 118               Government  Higher Education  ...  100K-150K     70
# 141                  Private  HS-Grad or lower  ...      <=50K     70
# 86                Government  Higher Education  ...   50K-100K     71
# 324  Self-Employed or No Pay  HS-Grad or lower  ...  100K-150K     71
# 103               Government  Higher Education  ...      150K+     73
# 58                Government  HS-Grad or lower  ...   50K-100K     74
# 32                Government  HS-Grad or lower  ...  100K-150K     74
# 318  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K     76
# 251                  Private  Higher Education  ...      150K+     78
# 323  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K     78
# 88                Government  Higher Education  ...  100K-150K     79
# 158                  Private  HS-Grad or lower  ...  100K-150K     79
# 162                  Private  HS-Grad or lower  ...  100K-150K     80
# 128               Government  Higher Education  ...   50K-100K     81
# 87                Government  Higher Education  ...      <=50K     81
# 113               Government  Higher Education  ...      <=50K     81
# 119               Government  Higher Education  ...      150K+     82
# 156                  Private  HS-Grad or lower  ...   50K-100K     83
# 409  Self-Employed or No Pay  Higher Education  ...   50K-100K     83
# 195                  Private  HS-Grad or lower  ...      150K+     85
# 213                  Private  Higher Education  ...      <=50K     85
# 226                  Private  Higher Education  ...  100K-150K     87
# 194                  Private  HS-Grad or lower  ...  100K-150K     90
# 123               Government  Higher Education  ...      150K+     90
# 178                  Private  HS-Grad or lower  ...  100K-150K     93
# 159                  Private  HS-Grad or lower  ...      150K+     95
# 325  Self-Employed or No Pay  HS-Grad or lower  ...      150K+     96
# 163                  Private  HS-Grad or lower  ...      150K+     96
# 278                  Private  Higher Education  ...  100K-150K     98
# 397  Self-Employed or No Pay  Higher Education  ...   50K-100K    100
# 33                Government  HS-Grad or lower  ...      150K+    101
# 227                  Private  Higher Education  ...      150K+    101
# 47                Government  HS-Grad or lower  ...      <=50K    105
# 150                  Private  HS-Grad or lower  ...  100K-150K    109
# 371  Self-Employed or No Pay  Higher Education  ...      <=50K    111
# 169                  Private  HS-Grad or lower  ...      <=50K    112
# 303  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K    113
# 89                Government  Higher Education  ...      150K+    113
# 104               Government  Higher Education  ...   50K-100K    113
# 129               Government  Higher Education  ...      <=50K    113
# 279                  Private  Higher Education  ...      150K+    113
# 302  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K    114
# 410  Self-Employed or No Pay  Higher Education  ...      <=50K    115
# 59                Government  HS-Grad or lower  ...      <=50K    117
# 157                  Private  HS-Grad or lower  ...      <=50K    118
# 366  Self-Employed or No Pay  Higher Education  ...   50K-100K    119
# 34                Government  HS-Grad or lower  ...   50K-100K    119
# 319  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K    120
# 124               Government  Higher Education  ...   50K-100K    122
# 114               Government  Higher Education  ...  100K-150K    126
# 179                  Private  HS-Grad or lower  ...      150K+    127
# 80                Government  Higher Education  ...  100K-150K    130
# 196                  Private  HS-Grad or lower  ...   50K-100K    131
# 206                  Private  HS-Grad or lower  ...  100K-150K    133
# 252                  Private  Higher Education  ...   50K-100K    135
# 120               Government  Higher Education  ...   50K-100K    135
# 151                  Private  HS-Grad or lower  ...      150K+    137
# 254                  Private  Higher Education  ...  100K-150K    140
# 372  Self-Employed or No Pay  Higher Education  ...  100K-150K    141
# 326  Self-Employed or No Pay  HS-Grad or lower  ...   50K-100K    144
# 105               Government  Higher Education  ...      <=50K    146
# 398  Self-Employed or No Pay  Higher Education  ...      <=50K    149
# 81                Government  Higher Education  ...      150K+    150
# 367  Self-Employed or No Pay  Higher Education  ...      <=50K    151
# 90                Government  Higher Education  ...   50K-100K    152
# 115               Government  Higher Education  ...      150K+    154
# 121               Government  Higher Education  ...      <=50K    156
# 164                  Private  HS-Grad or lower  ...   50K-100K    160
# 125               Government  Higher Education  ...      <=50K    163
# 190                  Private  HS-Grad or lower  ...  100K-150K    164
# 373  Self-Employed or No Pay  Higher Education  ...      150K+    166
# 229                  Private  Higher Education  ...      <=50K    173
# 327  Self-Employed or No Pay  HS-Grad or lower  ...      <=50K    174
# 253                  Private  Higher Education  ...      <=50K    177
# 35                Government  HS-Grad or lower  ...      <=50K    179
# 228                  Private  Higher Education  ...   50K-100K    184
# 255                  Private  Higher Education  ...      150K+    184
# 160                  Private  HS-Grad or lower  ...   50K-100K    187
# 186                  Private  HS-Grad or lower  ...  100K-150K    187
# 197                  Private  HS-Grad or lower  ...      <=50K    188
# 191                  Private  HS-Grad or lower  ...      150K+    190
# 165                  Private  HS-Grad or lower  ...      <=50K    194
# 180                  Private  HS-Grad or lower  ...   50K-100K    195
# 91                Government  Higher Education  ...      <=50K    198
# 82                Government  Higher Education  ...   50K-100K    205
# 207                  Private  HS-Grad or lower  ...      150K+    210
# 280                  Private  Higher Education  ...   50K-100K    211
# 182                  Private  HS-Grad or lower  ...  100K-150K    212
# 274                  Private  Higher Education  ...  100K-150K    219
# 246                  Private  Higher Education  ...  100K-150K    228
# 281                  Private  Higher Education  ...      <=50K    231
# 266                  Private  Higher Education  ...  100K-150K    231
# 152                  Private  HS-Grad or lower  ...   50K-100K    234
# 116               Government  Higher Education  ...   50K-100K    237
# 187                  Private  HS-Grad or lower  ...      150K+    239
# 247                  Private  Higher Education  ...      150K+    240
# 161                  Private  HS-Grad or lower  ...      <=50K    253
# 270                  Private  Higher Education  ...  100K-150K    257
# 181                  Private  HS-Grad or lower  ...      <=50K    267
# 262                  Private  Higher Education  ...  100K-150K    272
# 267                  Private  Higher Education  ...      150K+    278
# 256                  Private  Higher Education  ...   50K-100K    281
# 153                  Private  HS-Grad or lower  ...      <=50K    288
# 271                  Private  Higher Education  ...      150K+    291
# 208                  Private  HS-Grad or lower  ...   50K-100K    296
# 183                  Private  HS-Grad or lower  ...      150K+    297
# 222                  Private  Higher Education  ...  100K-150K    301
# 275                  Private  Higher Education  ...      150K+    301
# 374  Self-Employed or No Pay  Higher Education  ...   50K-100K    308
# 83                Government  Higher Education  ...      <=50K    313
# 117               Government  Higher Education  ...      <=50K    316
# 202                  Private  HS-Grad or lower  ...  100K-150K    321
# 263                  Private  Higher Education  ...      150K+    327
# 257                  Private  Higher Education  ...      <=50K    331
# 375  Self-Employed or No Pay  Higher Education  ...      <=50K    341
# 192                  Private  HS-Grad or lower  ...   50K-100K    346
# 230                  Private  Higher Education  ...  100K-150K    354
# 223                  Private  Higher Education  ...      150K+    362
# 203                  Private  HS-Grad or lower  ...      150K+    395
# 209                  Private  HS-Grad or lower  ...      <=50K    410
# 276                  Private  Higher Education  ...   50K-100K    426
# 193                  Private  HS-Grad or lower  ...      <=50K    428
# 188                  Private  HS-Grad or lower  ...   50K-100K    433
# 258                  Private  Higher Education  ...  100K-150K    445
# 248                  Private  Higher Education  ...   50K-100K    448
# 184                  Private  HS-Grad or lower  ...   50K-100K    457
# 174                  Private  HS-Grad or lower  ...  100K-150K    469
# 231                  Private  Higher Education  ...      150K+    470
# 198                  Private  HS-Grad or lower  ...  100K-150K    489
# 259                  Private  Higher Education  ...      150K+    504
# 272                  Private  Higher Education  ...   50K-100K    506
# 264                  Private  Higher Education  ...   50K-100K    512
# 268                  Private  Higher Education  ...   50K-100K    525
# 189                  Private  HS-Grad or lower  ...      <=50K    534
# 185                  Private  HS-Grad or lower  ...      <=50K    545
# 277                  Private  Higher Education  ...      <=50K    546
# 249                  Private  Higher Education  ...      <=50K    549
# 224                  Private  Higher Education  ...   50K-100K    590
# 175                  Private  HS-Grad or lower  ...      150K+    593
# 199                  Private  HS-Grad or lower  ...      150K+    599
# 204                  Private  HS-Grad or lower  ...   50K-100K    626
# 273                  Private  Higher Education  ...      <=50K    628
# 269                  Private  Higher Education  ...      <=50K    645
# 265                  Private  Higher Education  ...      <=50K    670
# 232                  Private  Higher Education  ...   50K-100K    766
# 225                  Private  Higher Education  ...      <=50K    779
# 260                  Private  Higher Education  ...   50K-100K    790
# 205                  Private  HS-Grad or lower  ...      <=50K    877
# 200                  Private  HS-Grad or lower  ...   50K-100K    914
# 176                  Private  HS-Grad or lower  ...   50K-100K    959
# 233                  Private  Higher Education  ...      <=50K    972
# 261                  Private  Higher Education  ...      <=50K   1000
# 177                  Private  HS-Grad or lower  ...      <=50K   1233
# 201                  Private  HS-Grad or lower  ...      <=50K   1252
#
# [423 rows x 8 columns]

# %%
grouped_df.shape
# Out:
# (423, 8)

# %%
adults_sub2.columns
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'hours-per-week', 'income', 'id-num'],
#       dtype='object')

# %%
adults_sub2.groupby(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week'])['income'].unique()
# Out:
# workclass                education         marital-status  occupation             relationship  hours-per-week
# Government               HS-Grad or lower  Married         Business Industry      Non-Spouse    40                [<=50K, 100K-150K, 50K-100K, 150K+]
#                                                                                                 <40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                   Spouse        40                [50K-100K, 150K+, 100K-150K, <=50K]
#                                                                                                 <40               [50K-100K, 150K+, <=50K, 100K-150K]
#                                                                                                 >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                            Non-Business Industry  Non-Spouse    40                [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                                                 <40               [50K-100K, 100K-150K, <=50K, 150K+]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                                   Spouse        40                [<=50K, 150K+, 50K-100K, 100K-150K]
#                                                                                                 <40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                                 >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                            Single          Business Industry      Non-Spouse    40                [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                                 <40               [50K-100K, 100K-150K, <=50K, 150K+]
#                                                                                                 >40               [150K+, <=50K, 50K-100K, 100K-150K]
#                                                            Non-Business Industry  Non-Spouse    40                [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                                                 <40               [100K-150K, 50K-100K, <=50K, 150K+]
#                                                                                                 >40               [<=50K, 150K+, 50K-100K, 100K-150K]
#                          Higher Education  Married         Business Industry      Non-Spouse    40                [50K-100K, 150K+, <=50K, 100K-150K]
#                                                                                                 <40               [<=50K, 100K-150K, 50K-100K, 150K+]
#                                                                                                 >40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                                                                   Spouse        40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 <40               [<=50K, 150K+, 50K-100K, 100K-150K]
#                                                                                                 >40               [150K+, 100K-150K, 50K-100K, <=50K]
#                                                            Non-Business Industry  Non-Spouse    40                [50K-100K, 150K+, <=50K, 100K-150K]
#                                                                                                 <40               [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 >40                             [50K-100K, 100K-150K]
#                                                                                   Spouse        40                [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                                                 <40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                                                                                 >40               [100K-150K, <=50K, 50K-100K, 150K+]
#                                            Single          Business Industry      Non-Spouse    40                [<=50K, 100K-150K, 50K-100K, 150K+]
#                                                                                                 <40               [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 >40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                            Non-Business Industry  Non-Spouse    40                [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 <40               [150K+, 50K-100K, 100K-150K, <=50K]
#                                                                                                 >40               [150K+, 100K-150K, <=50K, 50K-100K]
# Private                  HS-Grad or lower  Married         Business Industry      Non-Spouse    40                [150K+, 50K-100K, <=50K, 100K-150K]
#                                                                                                 <40               [100K-150K, 50K-100K, <=50K, 150K+]
#                                                                                                 >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                                                   Spouse        40                [100K-150K, <=50K, 150K+, 50K-100K]
#                                                                                                 <40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                            Non-Business Industry  Non-Spouse    40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                                                   Spouse        40                [<=50K, 150K+, 50K-100K, 100K-150K]
#                                                                                                 <40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                                 >40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                            Single          Business Industry      Non-Spouse    40                [150K+, 50K-100K, 100K-150K, <=50K]
#                                                                                                 <40               [50K-100K, 100K-150K, <=50K, 150K+]
#                                                                                                 >40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                            Non-Business Industry  Non-Spouse    40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 <40               [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                                                 >40               [<=50K, 100K-150K, 50K-100K, 150K+]
#                          Higher Education  Married         Business Industry      Non-Spouse    40                [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                                                 <40               [50K-100K, 150K+, 100K-150K, <=50K]
#                                                                                                 >40               [100K-150K, <=50K, 50K-100K, 150K+]
#                                                                                   Spouse        40                [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                                 <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 >40               [50K-100K, 150K+, 100K-150K, <=50K]
#                                                            Non-Business Industry  Non-Spouse    40                [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                                                 <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 >40               [50K-100K, 150K+, <=50K, 100K-150K]
#                                                                                   Spouse        40                [100K-150K, 150K+, 50K-100K, <=50K]
#                                                                                                 <40               [150K+, 50K-100K, 100K-150K, <=50K]
#                                                                                                 >40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                            Single          Business Industry      Non-Spouse    40                [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                                                 <40               [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                            Non-Business Industry  Non-Spouse    40                [100K-150K, <=50K, 150K+, 50K-100K]
#                                                                                                 <40               [100K-150K, 50K-100K, <=50K, 150K+]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
# Self-Employed or No Pay  HS-Grad or lower  Married         Business Industry      Non-Spouse    40                          [100K-150K, <=50K, 150K+]
#                                                                                                 <40                         [150K+, 100K-150K, <=50K]
#                                                                                                 >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                                                   Spouse        40                [100K-150K, 50K-100K, <=50K, 150K+]
#                                                                                                 <40               [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                                                 >40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                            Non-Business Industry  Non-Spouse    40                [150K+, 100K-150K, <=50K, 50K-100K]
#                                                                                                 <40               [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                                                 >40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                   Spouse        40                [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                                                 <40               [100K-150K, 150K+, <=50K, 50K-100K]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                            Single          Business Industry      Non-Spouse    40                [100K-150K, 150K+, <=50K, 50K-100K]
#                                                                                                 <40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                                                                 >40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                                            Non-Business Industry  Non-Spouse    40                [50K-100K, 150K+, 100K-150K, <=50K]
#                                                                                                 <40               [<=50K, 100K-150K, 150K+, 50K-100K]
#                                                                                                 >40               [150K+, 100K-150K, 50K-100K, <=50K]
#                          Higher Education  Married         Business Industry      Non-Spouse    40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 >40               [150K+, 50K-100K, 100K-150K, <=50K]
#                                                                                   Spouse        40                [50K-100K, 100K-150K, <=50K, 150K+]
#                                                                                                 <40               [100K-150K, <=50K, 50K-100K, 150K+]
#                                                                                                 >40               [50K-100K, 150K+, 100K-150K, <=50K]
#                                                            Non-Business Industry  Non-Spouse    40                       [100K-150K, <=50K, 50K-100K]
#                                                                                                 <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 >40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                   Spouse        40                [50K-100K, <=50K, 100K-150K, 150K+]
#                                                                                                 <40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                                                 >40               [150K+, <=50K, 50K-100K, 100K-150K]
#                                            Single          Business Industry      Non-Spouse    40                [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                                                 <40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                            Non-Business Industry  Non-Spouse    40                [50K-100K, <=50K, 100K-150K, 150K+]
#                                                                                                 <40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
# Name: income, dtype: object

# %%
# We  reached k-anonimity and 2 diversity as a direct consequence of k-anonimity
adults_sub2.groupby(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week'])['income'].value_counts()
# Out:
# workclass                education         marital-status  occupation             relationship  hours-per-week  income
# Government               HS-Grad or lower  Married         Business Industry      Non-Spouse    40              <=50K          15
#                                                                                                                 50K-100K        7
#                                                                                                                 100K-150K       6
#                                                                                                                 150K+           2
#                                                                                                 <40             50K-100K        8
#                                                                                                                 <=50K           5
#                                                                                                                 150K+           3
#                                                                                                                 100K-150K       1
#                                                                                   Spouse        40              <=50K          64
#                                                                                                                 50K-100K       49
#                                                                                                                 150K+          32
#                                                                                                                 100K-150K      26
#                                                                                                 <40             <=50K          21
#                                                                                                                 50K-100K        9
#                                                                                                                 100K-150K       7
#                                                                                                                 150K+           4
#                                                                                                 >40             <=50K          20
#                                                                                                                 50K-100K       16
#                                                                                                                 150K+           8
#                                                                                                                 100K-150K       3
#                                                            Non-Business Industry  Non-Spouse    40              <=50K          17
#                                                                                                                 50K-100K       11
#                                                                                                                 150K+           9
#                                                                                                                 100K-150K       6
#                                                                                                 <40             <=50K           7
#                                                                                                                 50K-100K        5
#                                                                                                                 100K-150K       3
#                                                                                                                 150K+           1
#                                                                                                 >40             50K-100K        8
#                                                                                                                 <=50K           5
#                                                                                                                 150K+           2
#                                                                                                                 100K-150K       1
#                                                                                   Spouse        40              <=50K         179
#                                                                                                                 50K-100K      119
#                                                                                                                 150K+         101
#                                                                                                                 100K-150K      74
#                                                                                                 <40             50K-100K       22
#                                                                                                                 <=50K          21
#                                                                                                                 150K+          16
#                                                                                                                 100K-150K      13
#                                                                                                 >40             <=50K          39
#                                                                                                                 50K-100K       24
#                                                                                                                 150K+          21
#                                                                                                                 100K-150K      15
#                                            Single          Business Industry      Non-Spouse    40              <=50K         105
#                                                                                                                 50K-100K       55
#                                                                                                                 150K+          53
#                                                                                                                 100K-150K      33
#                                                                                                 <40             <=50K          57
#                                                                                                                 50K-100K       29
#                                                                                                                 100K-150K      24
#                                                                                                                 150K+          23
#                                                                                                 >40             <=50K          18
#                                                                                                                 150K+           8
#                                                                                                                 50K-100K        7
#                                                                                                                 100K-150K       3
#                                                            Non-Business Industry  Non-Spouse    40              <=50K         117
#                                                                                                                 50K-100K       74
#                                                                                                                 150K+          56
#                                                                                                                 100K-150K      47
#                                                                                                 <40             50K-100K       47
#                                                                                                                 <=50K          39
#                                                                                                                 150K+          30
#                                                                                                                 100K-150K      20
#                                                                                                 >40             <=50K          26
#                                                                                                                 50K-100K       17
#                                                                                                                 150K+          11
#                                                                                                                 100K-150K       5
#                          Higher Education  Married         Business Industry      Non-Spouse    40              <=50K          35
#                                                                                                                 50K-100K       23
#                                                                                                                 100K-150K      15
#                                                                                                                 150K+          14
#                                                                                                 <40             50K-100K       10
#                                                                                                                 <=50K           8
#                                                                                                                 100K-150K       6
#                                                                                                                 150K+           6
#                                                                                                 >40             <=50K          15
#                                                                                                                 150K+           7
#                                                                                                                 50K-100K        6
#                                                                                                                 100K-150K       5
#                                                                                   Spouse        40              <=50K         313
#                                                                                                                 50K-100K      205
#                                                                                                                 150K+         150
#                                                                                                                 100K-150K     130
#                                                                                                 <40             <=50K          81
#                                                                                                                 50K-100K       71
#                                                                                                                 100K-150K      49
#                                                                                                                 150K+          41
#                                                                                                 >40             <=50K         198
#                                                                                                                 50K-100K      152
#                                                                                                                 150K+         113
#                                                                                                                 100K-150K      79
#                                                            Non-Business Industry  Non-Spouse    40              150K+           9
#                                                                                                                 <=50K           8
#                                                                                                                 50K-100K        6
#                                                                                                                 100K-150K       4
#                                                                                                 <40             <=50K           5
#                                                                                                                 50K-100K        3
#                                                                                                                 150K+           2
#                                                                                                                 100K-150K       1
#                                                                                                 >40             50K-100K        5
#                                                                                                                 100K-150K       3
#                                                                                   Spouse        40              <=50K         146
#                                                                                                                 50K-100K      113
#                                                                                                                 150K+          73
#                                                                                                                 100K-150K      46
#                                                                                                 <40             <=50K          18
#                                                                                                                 50K-100K       16
#                                                                                                                 150K+          12
#                                                                                                                 100K-150K       9
#                                                                                                 >40             <=50K          81
#                                                                                                                 50K-100K       54
#                                                                                                                 100K-150K      32
#                                                                                                                 150K+          26
#                                            Single          Business Industry      Non-Spouse    40              <=50K         316
#                                                                                                                 50K-100K      237
#                                                                                                                 150K+         154
#                                                                                                                 100K-150K     126
#                                                                                                 <40             <=50K         156
#                                                                                                                 50K-100K      135
#                                                                                                                 150K+          82
#                                                                                                                 100K-150K      70
#                                                                                                 >40             <=50K         163
#                                                                                                                 50K-100K      122
#                                                                                                                 150K+          90
#                                                                                                                 100K-150K      61
#                                                            Non-Business Industry  Non-Spouse    40              <=50K         113
#                                                                                                                 50K-100K       81
#                                                                                                                 150K+          54
#                                                                                                                 100K-150K      27
#                                                                                                 <40             50K-100K       43
#                                                                                                                 <=50K          36
#                                                                                                                 150K+          30
#                                                                                                                 100K-150K      14
#                                                                                                 >40             <=50K          34
#                                                                                                                 50K-100K       29
#                                                                                                                 150K+          27
#                                                                                                                 100K-150K      16
# Private                  HS-Grad or lower  Married         Business Industry      Non-Spouse    40              <=50K          70
#                                                                                                                 50K-100K       45
#                                                                                                                 150K+          29
#                                                                                                                 100K-150K      25
#                                                                                                 <40             <=50K          45
#                                                                                                                 50K-100K       35
#                                                                                                                 150K+          21
#                                                                                                                 100K-150K      16
#                                                                                                 >40             50K-100K       25
#                                                                                                                 <=50K          13
#                                                                                                                 100K-150K      11
#                                                                                                                 150K+           5
#                                                                                   Spouse        40              <=50K         288
#                                                                                                                 50K-100K      234
#                                                                                                                 150K+         137
#                                                                                                                 100K-150K     109
#                                                                                                 <40             <=50K         118
#                                                                                                                 50K-100K       83
#                                                                                                                 150K+          56
#                                                                                                                 100K-150K      50
#                                                                                                 >40             <=50K         253
#                                                                                                                 50K-100K      187
#                                                                                                                 150K+          95
#                                                                                                                 100K-150K      79
#                                                            Non-Business Industry  Non-Spouse    40              <=50K         194
#                                                                                                                 50K-100K      160
#                                                                                                                 150K+          96
#                                                                                                                 100K-150K      80
#                                                                                                 <40             <=50K         112
#                                                                                                                 50K-100K       69
#                                                                                                                 150K+          39
#                                                                                                                 100K-150K      35
#                                                                                                 >40             <=50K          50
#                                                                                                                 50K-100K       39
#                                                                                                                 150K+          32
#                                                                                                                 100K-150K      18
#                                                                                   Spouse        40              <=50K        1233
#                                                                                                                 50K-100K      959
#                                                                                                                 150K+         593
#                                                                                                                 100K-150K     469
#                                                                                                 <40             <=50K         267
#                                                                                                                 50K-100K      195
#                                                                                                                 150K+         127
#                                                                                                                 100K-150K      93
#                                                                                                 >40             <=50K         545
#                                                                                                                 50K-100K      457
#                                                                                                                 150K+         297
#                                                                                                                 100K-150K     212
#                                            Single          Business Industry      Non-Spouse    40              <=50K         534
#                                                                                                                 50K-100K      433
#                                                                                                                 150K+         239
#                                                                                                                 100K-150K     187
#                                                                                                 <40             <=50K         428
#                                                                                                                 50K-100K      346
#                                                                                                                 150K+         190
#                                                                                                                 100K-150K     164
#                                                                                                 >40             <=50K         188
#                                                                                                                 50K-100K      131
#                                                                                                                 100K-150K      90
#                                                                                                                 150K+          85
#                                                            Non-Business Industry  Non-Spouse    40              <=50K        1252
#                                                                                                                 50K-100K      914
#                                                                                                                 150K+         599
#                                                                                                                 100K-150K     489
#                                                                                                 <40             <=50K         877
#                                                                                                                 50K-100K      626
#                                                                                                                 150K+         395
#                                                                                                                 100K-150K     321
#                                                                                                 >40             <=50K         410
#                                                                                                                 50K-100K      296
#                                                                                                                 150K+         210
#                                                                                                                 100K-150K     133
#                          Higher Education  Married         Business Industry      Non-Spouse    40              <=50K          85
#                                                                                                                 50K-100K       61
#                                                                                                                 150K+          51
#                                                                                                                 100K-150K      30
#                                                                                                 <40             50K-100K       38
#                                                                                                                 <=50K          38
#                                                                                                                 150K+          18
#                                                                                                                 100K-150K      11
#                                                                                                 >40             <=50K          37
#                                                                                                                 50K-100K       31
#                                                                                                                 100K-150K      24
#                                                                                                                 150K+          24
#                                                                                   Spouse        40              <=50K         779
#                                                                                                                 50K-100K      590
#                                                                                                                 150K+         362
#                                                                                                                 100K-150K     301
#                                                                                                 <40             50K-100K      184
#                                                                                                                 <=50K         173
#                                                                                                                 150K+         101
#                                                                                                                 100K-150K      87
#                                                                                                 >40             <=50K         972
#                                                                                                                 50K-100K      766
#                                                                                                                 150K+         470
#                                                                                                                 100K-150K     354
#                                                            Non-Business Industry  Non-Spouse    40              <=50K          55
#                                                                                                                 50K-100K       40
#                                                                                                                 150K+          34
#                                                                                                                 100K-150K      18
#                                                                                                 <40             <=50K          27
#                                                                                                                 50K-100K       24
#                                                                                                                 100K-150K      16
#                                                                                                                 150K+          16
#                                                                                                 >40             <=50K          30
#                                                                                                                 50K-100K       21
#                                                                                                                 100K-150K       8
#                                                                                                                 150K+           8
#                                                                                   Spouse        40              <=50K         549
#                                                                                                                 50K-100K      448
#                                                                                                                 150K+         240
#                                                                                                                 100K-150K     228
#                                                                                                 <40             <=50K         177
#                                                                                                                 50K-100K      135
#                                                                                                                 150K+          78
#                                                                                                                 100K-150K      67
#                                                                                                 >40             <=50K         331
#                                                                                                                 50K-100K      281
#                                                                                                                 150K+         184
#                                                                                                                 100K-150K     140
#                                            Single          Business Industry      Non-Spouse    40              <=50K        1000
#                                                                                                                 50K-100K      790
#                                                                                                                 150K+         504
#                                                                                                                 100K-150K     445
#                                                                                                 <40             <=50K         670
#                                                                                                                 50K-100K      512
#                                                                                                                 150K+         327
#                                                                                                                 100K-150K     272
#                                                                                                 >40             <=50K         645
#                                                                                                                 50K-100K      525
#                                                                                                                 150K+         278
#                                                                                                                 100K-150K     231
#                                                            Non-Business Industry  Non-Spouse    40              <=50K         628
#                                                                                                                 50K-100K      506
#                                                                                                                 150K+         291
#                                                                                                                 100K-150K     257
#                                                                                                 <40             <=50K         546
#                                                                                                                 50K-100K      426
#                                                                                                                 150K+         301
#                                                                                                                 100K-150K     219
#                                                                                                 >40             <=50K         231
#                                                                                                                 50K-100K      211
#                                                                                                                 150K+         113
#                                                                                                                 100K-150K      98
# Self-Employed or No Pay  HS-Grad or lower  Married         Business Industry      Non-Spouse    40              <=50K           3
#                                                                                                                 100K-150K       2
#                                                                                                                 150K+           2
#                                                                                                 <40             <=50K           5
#                                                                                                                 150K+           3
#                                                                                                                 100K-150K       2
#                                                                                                 >40             50K-100K        5
#                                                                                                                 100K-150K       2
#                                                                                                                 150K+           1
#                                                                                                                 <=50K           1
#                                                                                   Spouse        40              <=50K          60
#                                                                                                                 50K-100K       47
#                                                                                                                 150K+          32
#                                                                                                                 100K-150K      25
#                                                                                                 <40             <=50K          36
#                                                                                                                 50K-100K       34
#                                                                                                                 100K-150K      29
#                                                                                                                 150K+          16
#                                                                                                 >40             50K-100K      114
#                                                                                                                 <=50K         113
#                                                                                                                 100K-150K      56
#                                                                                                                 150K+          41
#                                                            Non-Business Industry  Non-Spouse    40              <=50K           9
#                                                                                                                 100K-150K       7
#                                                                                                                 50K-100K        5
#                                                                                                                 150K+           2
#                                                                                                 <40             <=50K           6
#                                                                                                                 150K+           4
#                                                                                                                 100K-150K       2
#                                                                                                                 50K-100K        2
#                                                                                                 >40             <=50K          12
#                                                                                                                 50K-100K        7
#                                                                                                                 150K+           6
#                                                                                                                 100K-150K       2
#                                                                                   Spouse        40              <=50K         120
#                                                                                                                 50K-100K       76
#                                                                                                                 150K+          52
#                                                                                                                 100K-150K      40
#                                                                                                 <40             <=50K          78
#                                                                                                                 50K-100K       54
#                                                                                                                 150K+          39
#                                                                                                                 100K-150K      27
#                                                                                                 >40             <=50K         174
#                                                                                                                 50K-100K      144
#                                                                                                                 150K+          96
#                                                                                                                 100K-150K      71
#                                            Single          Business Industry      Non-Spouse    40              <=50K          26
#                                                                                                                 50K-100K       16
#                                                                                                                 150K+          11
#                                                                                                                 100K-150K       9
#                                                                                                 <40             <=50K          31
#                                                                                                                 50K-100K       14
#                                                                                                                 150K+          10
#                                                                                                                 100K-150K       5
#                                                                                                 >40             <=50K          35
#                                                                                                                 50K-100K       31
#                                                                                                                 100K-150K      22
#                                                                                                                 150K+           9
#                                                            Non-Business Industry  Non-Spouse    40              <=50K          55
#                                                                                                                 50K-100K       37
#                                                                                                                 150K+          26
#                                                                                                                 100K-150K      18
#                                                                                                 <40             <=50K          62
#                                                                                                                 50K-100K       43
#                                                                                                                 100K-150K      21
#                                                                                                                 150K+          16
#                                                                                                 >40             <=50K          60
#                                                                                                                 50K-100K       41
#                                                                                                                 150K+          34
#                                                                                                                 100K-150K      30
#                          Higher Education  Married         Business Industry      Non-Spouse    40              50K-100K        8
#                                                                                                                 <=50K           6
#                                                                                                                 150K+           5
#                                                                                                                 100K-150K       2
#                                                                                                 <40             150K+           6
#                                                                                                                 <=50K           6
#                                                                                                                 50K-100K        4
#                                                                                                                 100K-150K       1
#                                                                                                 >40             <=50K          13
#                                                                                                                 50K-100K       10
#                                                                                                                 150K+           8
#                                                                                                                 100K-150K       4
#                                                                                   Spouse        40              <=50K         151
#                                                                                                                 50K-100K      119
#                                                                                                                 150K+          62
#                                                                                                                 100K-150K      52
#                                                                                                 <40             <=50K         111
#                                                                                                                 50K-100K       66
#                                                                                                                 150K+          63
#                                                                                                                 100K-150K      40
#                                                                                                 >40             <=50K         341
#                                                                                                                 50K-100K      308
#                                                                                                                 150K+         166
#                                                                                                                 100K-150K     141
#                                                            Non-Business Industry  Non-Spouse    40              <=50K           4
#                                                                                                                 100K-150K       2
#                                                                                                                 50K-100K        2
#                                                                                                 <40             <=50K           6
#                                                                                                                 50K-100K        4
#                                                                                                                 100K-150K       1
#                                                                                                                 150K+           1
#                                                                                                 >40             50K-100K        6
#                                                                                                                 <=50K           6
#                                                                                                                 150K+           4
#                                                                                                                 100K-150K       1
#                                                                                   Spouse        40              <=50K          58
#                                                                                                                 50K-100K       43
#                                                                                                                 100K-150K      25
#                                                                                                                 150K+          23
#                                                                                                 <40             <=50K          35
#                                                                                                                 50K-100K       28
#                                                                                                                 150K+          19
#                                                                                                                 100K-150K      16
#                                                                                                 >40             <=50K         149
#                                                                                                                 50K-100K      100
#                                                                                                                 150K+          67
#                                                                                                                 100K-150K      46
#                                            Single          Business Industry      Non-Spouse    40              <=50K          55
#                                                                                                                 50K-100K       47
#                                                                                                                 150K+          23
#                                                                                                                 100K-150K      21
#                                                                                                 <40             <=50K          55
#                                                                                                                 50K-100K       50
#                                                                                                                 150K+          30
#                                                                                                                 100K-150K      21
#                                                                                                 >40             <=50K         115
#                                                                                                                 50K-100K       83
#                                                                                                                 100K-150K      61
#                                                                                                                 150K+          58
#                                                            Non-Business Industry  Non-Spouse    40              <=50K          35
#                                                                                                                 50K-100K       32
#                                                                                                                 150K+          21
#                                                                                                                 100K-150K      12
#                                                                                                 <40             50K-100K       32
#                                                                                                                 <=50K          30
#                                                                                                                 150K+          22
#                                                                                                                 100K-150K      11
#                                                                                                 >40             <=50K          41
#                                                                                                                 50K-100K       29
#                                                                                                                 150K+          21
#                                                                                                                 100K-150K      18
# Name: income, dtype: int64

# %%
grouped_df = adults_sub2.groupby(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week']).size().reset_index(name='counts')

# %%
# We reached 7-anonimity
grouped_df.sort_values("counts", ascending=True)
# Out:
#                    workclass         education  ... hours-per-week counts
# 71   Self-Employed or No Pay  HS-Grad or lower  ...             40      7
# 95   Self-Employed or No Pay  Higher Education  ...             40      8
# 25                Government  Higher Education  ...            >40      8
# 73   Self-Employed or No Pay  HS-Grad or lower  ...            >40      9
# 72   Self-Employed or No Pay  HS-Grad or lower  ...            <40     10
# 24                Government  Higher Education  ...            <40     11
# 96   Self-Employed or No Pay  Higher Education  ...            <40     12
# 78   Self-Employed or No Pay  HS-Grad or lower  ...            <40     14
# 6                 Government  HS-Grad or lower  ...            <40     16
# 7                 Government  HS-Grad or lower  ...            >40     16
# 97   Self-Employed or No Pay  Higher Education  ...            >40     17
# 90   Self-Employed or No Pay  Higher Education  ...            <40     17
# 1                 Government  HS-Grad or lower  ...            <40     17
# 89   Self-Employed or No Pay  Higher Education  ...             40     21
# 77   Self-Employed or No Pay  HS-Grad or lower  ...             40     23
# 23                Government  Higher Education  ...             40     27
# 79   Self-Employed or No Pay  HS-Grad or lower  ...            >40     27
# 18                Government  Higher Education  ...            <40     30
# 0                 Government  HS-Grad or lower  ...             40     30
# 19                Government  Higher Education  ...            >40     33
# 91   Self-Employed or No Pay  Higher Education  ...            >40     35
# 13                Government  HS-Grad or lower  ...            >40     36
# 3                 Government  HS-Grad or lower  ...            <40     41
# 5                 Government  HS-Grad or lower  ...             40     43
# 4                 Government  HS-Grad or lower  ...            >40     47
# 37                   Private  HS-Grad or lower  ...            >40     54
# 27                Government  Higher Education  ...            <40     55
# 16                Government  HS-Grad or lower  ...            >40     59
# 84   Self-Employed or No Pay  HS-Grad or lower  ...            <40     60
# 83   Self-Employed or No Pay  HS-Grad or lower  ...             40     62
# 61                   Private  Higher Education  ...            >40     67
# 9                 Government  HS-Grad or lower  ...            <40     72
# 60                   Private  Higher Education  ...            <40     83
# 17                Government  Higher Education  ...             40     87
# 105  Self-Employed or No Pay  Higher Education  ...            <40     95
# 85   Self-Employed or No Pay  HS-Grad or lower  ...            >40     97
# 99   Self-Employed or No Pay  Higher Education  ...            <40     98
# 10                Government  HS-Grad or lower  ...            >40     99
# 104  Self-Employed or No Pay  Higher Education  ...             40    100
# 54                   Private  Higher Education  ...            <40    105
# 34                Government  Higher Education  ...            >40    106
# 106  Self-Employed or No Pay  Higher Education  ...            >40    109
# 75   Self-Employed or No Pay  HS-Grad or lower  ...            <40    115
# 55                   Private  Higher Education  ...            >40    116
# 36                   Private  HS-Grad or lower  ...            <40    117
# 33                Government  Higher Education  ...            <40    123
# 12                Government  HS-Grad or lower  ...            <40    133
# 86   Self-Employed or No Pay  HS-Grad or lower  ...             40    136
# 15                Government  HS-Grad or lower  ...            <40    136
# 43                   Private  HS-Grad or lower  ...            >40    139
# 87   Self-Employed or No Pay  HS-Grad or lower  ...            <40    142
# 101  Self-Employed or No Pay  Higher Education  ...             40    146
# 59                   Private  Higher Education  ...             40    147
# 98   Self-Employed or No Pay  Higher Education  ...             40    149
# 102  Self-Employed or No Pay  Higher Education  ...            <40    156
# 74   Self-Employed or No Pay  HS-Grad or lower  ...             40    164
# 88   Self-Employed or No Pay  HS-Grad or lower  ...            >40    165
# 35                   Private  HS-Grad or lower  ...             40    169
# 2                 Government  HS-Grad or lower  ...             40    171
# 28                Government  Higher Education  ...            >40    193
# 81   Self-Employed or No Pay  HS-Grad or lower  ...            <40    198
# 53                   Private  Higher Education  ...             40    227
# 21                Government  Higher Education  ...            <40    242
# 11                Government  HS-Grad or lower  ...             40    246
# 42                   Private  HS-Grad or lower  ...            <40    255
# 32                Government  Higher Education  ...             40    275
# 93   Self-Employed or No Pay  Higher Education  ...            <40    280
# 80   Self-Employed or No Pay  HS-Grad or lower  ...             40    288
# 14                Government  HS-Grad or lower  ...             40    294
# 39                   Private  HS-Grad or lower  ...            <40    307
# 103  Self-Employed or No Pay  Higher Education  ...            >40    317
# 76   Self-Employed or No Pay  HS-Grad or lower  ...            >40    324
# 100  Self-Employed or No Pay  Higher Education  ...            >40    362
# 26                Government  Higher Education  ...             40    378
# 92   Self-Employed or No Pay  Higher Education  ...             40    384
# 31                Government  Higher Education  ...            >40    436
# 30                Government  Higher Education  ...            <40    443
# 63                   Private  Higher Education  ...            <40    457
# 8                 Government  HS-Grad or lower  ...             40    473
# 82   Self-Employed or No Pay  HS-Grad or lower  ...            >40    485
# 49                   Private  HS-Grad or lower  ...            >40    494
# 41                   Private  HS-Grad or lower  ...             40    530
# 22                Government  Higher Education  ...            >40    542
# 57                   Private  Higher Education  ...            <40    545
# 40                   Private  HS-Grad or lower  ...            >40    614
# 70                   Private  Higher Education  ...            >40    653
# 45                   Private  HS-Grad or lower  ...            <40    682
# 38                   Private  HS-Grad or lower  ...             40    768
# 20                Government  Higher Education  ...             40    798
# 29                Government  Higher Education  ...             40    833
# 64                   Private  Higher Education  ...            >40    936
# 94   Self-Employed or No Pay  Higher Education  ...            >40    956
# 52                   Private  HS-Grad or lower  ...            >40   1049
# 48                   Private  HS-Grad or lower  ...            <40   1128
# 47                   Private  HS-Grad or lower  ...             40   1393
# 62                   Private  Higher Education  ...             40   1465
# 69                   Private  Higher Education  ...            <40   1492
# 46                   Private  HS-Grad or lower  ...            >40   1511
# 67                   Private  Higher Education  ...            >40   1679
# 68                   Private  Higher Education  ...             40   1682
# 66                   Private  Higher Education  ...            <40   1781
# 56                   Private  Higher Education  ...             40   2032
# 51                   Private  HS-Grad or lower  ...            <40   2219
# 58                   Private  Higher Education  ...            >40   2562
# 65                   Private  Higher Education  ...             40   2739
# 44                   Private  HS-Grad or lower  ...             40   3254
# 50                   Private  HS-Grad or lower  ...             40   3254
#
# [107 rows x 7 columns]

# %% [markdown]
# # L-diversity

# %%
# We see that 2 diversity is reached, but not 4 diversity, so our solution can be improved further
adults_sub2.groupby(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week'])['income'].unique()
# Out:
# workclass                education         marital-status  occupation             relationship  hours-per-week
# Government               HS-Grad or lower  Married         Business Industry      Non-Spouse    40                [<=50K, 100K-150K, 50K-100K, 150K+]
#                                                                                                 <40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                   Spouse        40                [50K-100K, 150K+, 100K-150K, <=50K]
#                                                                                                 <40               [50K-100K, 150K+, <=50K, 100K-150K]
#                                                                                                 >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                            Non-Business Industry  Non-Spouse    40                [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                                                 <40               [50K-100K, 100K-150K, <=50K, 150K+]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                                   Spouse        40                [<=50K, 150K+, 50K-100K, 100K-150K]
#                                                                                                 <40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                                 >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                            Single          Business Industry      Non-Spouse    40                [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                                 <40               [50K-100K, 100K-150K, <=50K, 150K+]
#                                                                                                 >40               [150K+, <=50K, 50K-100K, 100K-150K]
#                                                            Non-Business Industry  Non-Spouse    40                [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                                                 <40               [100K-150K, 50K-100K, <=50K, 150K+]
#                                                                                                 >40               [<=50K, 150K+, 50K-100K, 100K-150K]
#                          Higher Education  Married         Business Industry      Non-Spouse    40                [50K-100K, 150K+, <=50K, 100K-150K]
#                                                                                                 <40               [<=50K, 100K-150K, 50K-100K, 150K+]
#                                                                                                 >40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                                                                   Spouse        40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 <40               [<=50K, 150K+, 50K-100K, 100K-150K]
#                                                                                                 >40               [150K+, 100K-150K, 50K-100K, <=50K]
#                                                            Non-Business Industry  Non-Spouse    40                [50K-100K, 150K+, <=50K, 100K-150K]
#                                                                                                 <40               [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 >40                             [50K-100K, 100K-150K]
#                                                                                   Spouse        40                [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                                                 <40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                                                                                 >40               [100K-150K, <=50K, 50K-100K, 150K+]
#                                            Single          Business Industry      Non-Spouse    40                [<=50K, 100K-150K, 50K-100K, 150K+]
#                                                                                                 <40               [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 >40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                            Non-Business Industry  Non-Spouse    40                [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 <40               [150K+, 50K-100K, 100K-150K, <=50K]
#                                                                                                 >40               [150K+, 100K-150K, <=50K, 50K-100K]
# Private                  HS-Grad or lower  Married         Business Industry      Non-Spouse    40                [150K+, 50K-100K, <=50K, 100K-150K]
#                                                                                                 <40               [100K-150K, 50K-100K, <=50K, 150K+]
#                                                                                                 >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                                                   Spouse        40                [100K-150K, <=50K, 150K+, 50K-100K]
#                                                                                                 <40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                            Non-Business Industry  Non-Spouse    40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                                                   Spouse        40                [<=50K, 150K+, 50K-100K, 100K-150K]
#                                                                                                 <40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                                 >40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                            Single          Business Industry      Non-Spouse    40                [150K+, 50K-100K, 100K-150K, <=50K]
#                                                                                                 <40               [50K-100K, 100K-150K, <=50K, 150K+]
#                                                                                                 >40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                            Non-Business Industry  Non-Spouse    40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 <40               [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                                                 >40               [<=50K, 100K-150K, 50K-100K, 150K+]
#                          Higher Education  Married         Business Industry      Non-Spouse    40                [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                                                 <40               [50K-100K, 150K+, 100K-150K, <=50K]
#                                                                                                 >40               [100K-150K, <=50K, 50K-100K, 150K+]
#                                                                                   Spouse        40                [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                                 <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 >40               [50K-100K, 150K+, 100K-150K, <=50K]
#                                                            Non-Business Industry  Non-Spouse    40                [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                                                 <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 >40               [50K-100K, 150K+, <=50K, 100K-150K]
#                                                                                   Spouse        40                [100K-150K, 150K+, 50K-100K, <=50K]
#                                                                                                 <40               [150K+, 50K-100K, 100K-150K, <=50K]
#                                                                                                 >40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                            Single          Business Industry      Non-Spouse    40                [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                                                 <40               [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                            Non-Business Industry  Non-Spouse    40                [100K-150K, <=50K, 150K+, 50K-100K]
#                                                                                                 <40               [100K-150K, 50K-100K, <=50K, 150K+]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
# Self-Employed or No Pay  HS-Grad or lower  Married         Business Industry      Non-Spouse    40                          [100K-150K, <=50K, 150K+]
#                                                                                                 <40                         [150K+, 100K-150K, <=50K]
#                                                                                                 >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                                                   Spouse        40                [100K-150K, 50K-100K, <=50K, 150K+]
#                                                                                                 <40               [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                                                 >40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                            Non-Business Industry  Non-Spouse    40                [150K+, 100K-150K, <=50K, 50K-100K]
#                                                                                                 <40               [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                                                 >40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                   Spouse        40                [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                                                 <40               [100K-150K, 150K+, <=50K, 50K-100K]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                            Single          Business Industry      Non-Spouse    40                [100K-150K, 150K+, <=50K, 50K-100K]
#                                                                                                 <40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                                                                 >40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                                            Non-Business Industry  Non-Spouse    40                [50K-100K, 150K+, 100K-150K, <=50K]
#                                                                                                 <40               [<=50K, 100K-150K, 150K+, 50K-100K]
#                                                                                                 >40               [150K+, 100K-150K, 50K-100K, <=50K]
#                          Higher Education  Married         Business Industry      Non-Spouse    40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                                                 <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 >40               [150K+, 50K-100K, 100K-150K, <=50K]
#                                                                                   Spouse        40                [50K-100K, 100K-150K, <=50K, 150K+]
#                                                                                                 <40               [100K-150K, <=50K, 50K-100K, 150K+]
#                                                                                                 >40               [50K-100K, 150K+, 100K-150K, <=50K]
#                                                            Non-Business Industry  Non-Spouse    40                       [100K-150K, <=50K, 50K-100K]
#                                                                                                 <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                                 >40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                                   Spouse        40                [50K-100K, <=50K, 100K-150K, 150K+]
#                                                                                                 <40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                                                 >40               [150K+, <=50K, 50K-100K, 100K-150K]
#                                            Single          Business Industry      Non-Spouse    40                [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                                                 <40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                            Non-Business Industry  Non-Spouse    40                [50K-100K, <=50K, 100K-150K, 150K+]
#                                                                                                 <40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                                                 >40               [50K-100K, <=50K, 150K+, 100K-150K]
# Name: income, dtype: object

# %%
for column in adults_sub2:
  print("Value counts for column ", column, " are: ")
  print(adults_sub2[column].value_counts(), '\n')
# Out:
# Value counts for column  workclass  are:
# Private                    36705
# Government                  6549
# Self-Employed or No Pay     5588
# Name: workclass, dtype: int64
#
# Value counts for column  education  are:
# Higher Education    26650
# HS-Grad or lower    22192
# Name: education, dtype: int64
#
# Value counts for column  marital-status  are:
# Married    24574
# Single     24268
# Name: marital-status, dtype: int64
#
# Value counts for column  occupation  are:
# Non-Business Industry    24687
# Business Industry        24155
# Name: occupation, dtype: int64
#
# Value counts for column  relationship  are:
# Non-Spouse    26795
# Spouse        22047
# Name: relationship, dtype: int64
#
# Value counts for column  hours-per-week  are:
# 40     22803
# >40    14352
# <40    11687
# Name: hours-per-week, dtype: int64
#
# Value counts for column  income  are:
# <=50K        18434
# 50K-100K     14282
# 150K+         8914
# 100K-150K     7212
# Name: income, dtype: int64
#
# Value counts for column  id-num  are:
# 67583    1
# 23873    1
# 50514    1
# 56657    1
# 54608    1
#         ..
# 51852    1
# 62091    1
# 64138    1
# 57993    1
# 65536    1
# Name: id-num, Length: 48842, dtype: int64

# %%
adults_sub3 = adults_sub2.drop(columns=["workclass"])

# %%
grouped_df = adults_sub3.groupby(['education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week']).size().reset_index(name='counts')

# %%
# With dropping workclass we have reached k-anonimity with value 63
grouped_df.sort_values("counts", ascending=True)
# Out:
#            education marital-status  ... hours-per-week counts
# 2   HS-Grad or lower        Married  ...            >40     63
# 26  Higher Education        Married  ...            >40     92
# 25  Higher Education        Married  ...            <40    106
# 1   HS-Grad or lower        Married  ...            <40    144
# 19  Higher Education        Married  ...            <40    152
# 8   HS-Grad or lower        Married  ...            >40    182
# 24  Higher Education        Married  ...             40    182
# 20  Higher Education        Married  ...            >40    184
# 0   HS-Grad or lower        Married  ...             40    206
# 7   HS-Grad or lower        Married  ...            <40    285
# 18  Higher Education        Married  ...             40    335
# 4   HS-Grad or lower        Married  ...            <40    463
# 6   HS-Grad or lower        Married  ...             40    596
# 28  Higher Education        Married  ...            <40    610
# 14  HS-Grad or lower         Single  ...            >40    627
# 35  Higher Education         Single  ...            >40    868
# 10  HS-Grad or lower        Married  ...            <40    952
# 5   HS-Grad or lower        Married  ...            >40    985
# 22  Higher Education        Married  ...            <40   1067
# 3   HS-Grad or lower        Married  ...             40   1103
# 17  HS-Grad or lower         Single  ...            >40   1273
# 13  HS-Grad or lower         Single  ...            <40   1321
# 29  Higher Education        Married  ...            >40   1491
# 12  HS-Grad or lower         Single  ...             40   1701
# 34  Higher Education         Single  ...            <40   1710
# 27  Higher Education        Married  ...             40   1992
# 33  Higher Education         Single  ...             40   2057
# 11  HS-Grad or lower        Married  ...            >40   2095
# 31  Higher Education         Single  ...            <40   2380
# 32  Higher Education         Single  ...            >40   2432
# 16  HS-Grad or lower         Single  ...            <40   2497
# 21  Higher Education        Married  ...             40   3214
# 15  HS-Grad or lower         Single  ...             40   3684
# 30  Higher Education         Single  ...             40   3718
# 9   HS-Grad or lower        Married  ...             40   4015
# 23  Higher Education        Married  ...            >40   4060
#
# [36 rows x 6 columns]

# %%
# We have 36 classes of equivalence
grouped_df.shape
# Out:
# (36, 6)

# %%
grouped_df2 = adults_sub3.groupby(['education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week']).size().reset_index(name = "counts")

# %%
grouped_df2.sort_values("counts", ascending=True)
# Out:
#            education marital-status  ... hours-per-week counts
# 2   HS-Grad or lower        Married  ...            >40     63
# 26  Higher Education        Married  ...            >40     92
# 25  Higher Education        Married  ...            <40    106
# 1   HS-Grad or lower        Married  ...            <40    144
# 19  Higher Education        Married  ...            <40    152
# 8   HS-Grad or lower        Married  ...            >40    182
# 24  Higher Education        Married  ...             40    182
# 20  Higher Education        Married  ...            >40    184
# 0   HS-Grad or lower        Married  ...             40    206
# 7   HS-Grad or lower        Married  ...            <40    285
# 18  Higher Education        Married  ...             40    335
# 4   HS-Grad or lower        Married  ...            <40    463
# 6   HS-Grad or lower        Married  ...             40    596
# 28  Higher Education        Married  ...            <40    610
# 14  HS-Grad or lower         Single  ...            >40    627
# 35  Higher Education         Single  ...            >40    868
# 10  HS-Grad or lower        Married  ...            <40    952
# 5   HS-Grad or lower        Married  ...            >40    985
# 22  Higher Education        Married  ...            <40   1067
# 3   HS-Grad or lower        Married  ...             40   1103
# 17  HS-Grad or lower         Single  ...            >40   1273
# 13  HS-Grad or lower         Single  ...            <40   1321
# 29  Higher Education        Married  ...            >40   1491
# 12  HS-Grad or lower         Single  ...             40   1701
# 34  Higher Education         Single  ...            <40   1710
# 27  Higher Education        Married  ...             40   1992
# 33  Higher Education         Single  ...             40   2057
# 11  HS-Grad or lower        Married  ...            >40   2095
# 31  Higher Education         Single  ...            <40   2380
# 32  Higher Education         Single  ...            >40   2432
# 16  HS-Grad or lower         Single  ...            <40   2497
# 21  Higher Education        Married  ...             40   3214
# 15  HS-Grad or lower         Single  ...             40   3684
# 30  Higher Education         Single  ...             40   3718
# 9   HS-Grad or lower        Married  ...             40   4015
# 23  Higher Education        Married  ...            >40   4060
#
# [36 rows x 6 columns]

# %%
grouped_df2.shape
# Out:
# (36, 6)

# %%
adults_sub3.groupby(['education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week'])["income"].unique()
# Out:
# education         marital-status  occupation             relationship  hours-per-week
# HS-Grad or lower  Married         Business Industry      Non-Spouse    40                [150K+, 50K-100K, <=50K, 100K-150K]
#                                                                        <40               [100K-150K, <=50K, 50K-100K, 150K+]
#                                                                        >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                          Spouse        40                [100K-150K, <=50K, 150K+, 50K-100K]
#                                                                        <40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                        >40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                   Non-Business Industry  Non-Spouse    40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                        <40               [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                        >40               [50K-100K, 100K-150K, 150K+, <=50K]
#                                                          Spouse        40                [<=50K, 150K+, 50K-100K, 100K-150K]
#                                                                        <40               [<=50K, 50K-100K, 100K-150K, 150K+]
#                                                                        >40               [50K-100K, <=50K, 100K-150K, 150K+]
#                   Single          Business Industry      Non-Spouse    40                [150K+, 50K-100K, <=50K, 100K-150K]
#                                                                        <40               [50K-100K, 100K-150K, <=50K, 150K+]
#                                                                        >40               [50K-100K, <=50K, 100K-150K, 150K+]
#                                   Non-Business Industry  Non-Spouse    40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                        <40               [150K+, <=50K, 100K-150K, 50K-100K]
#                                                                        >40               [150K+, <=50K, 100K-150K, 50K-100K]
# Higher Education  Married         Business Industry      Non-Spouse    40                [50K-100K, 150K+, <=50K, 100K-150K]
#                                                                        <40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                        >40               [100K-150K, <=50K, 150K+, 50K-100K]
#                                                          Spouse        40                [150K+, <=50K, 50K-100K, 100K-150K]
#                                                                        <40               [100K-150K, <=50K, 50K-100K, 150K+]
#                                                                        >40               [50K-100K, 150K+, 100K-150K, <=50K]
#                                   Non-Business Industry  Non-Spouse    40                [<=50K, 50K-100K, 150K+, 100K-150K]
#                                                                        <40               [<=50K, 150K+, 50K-100K, 100K-150K]
#                                                                        >40               [50K-100K, 150K+, <=50K, 100K-150K]
#                                                          Spouse        40                [50K-100K, 100K-150K, <=50K, 150K+]
#                                                                        <40               [150K+, 50K-100K, 100K-150K, <=50K]
#                                                                        >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                   Single          Business Industry      Non-Spouse    40                [50K-100K, <=50K, 150K+, 100K-150K]
#                                                                        <40               [<=50K, 150K+, 100K-150K, 50K-100K]
#                                                                        >40               [50K-100K, <=50K, 150K+, 100K-150K]
#                                   Non-Business Industry  Non-Spouse    40                [100K-150K, <=50K, 150K+, 50K-100K]
#                                                                        <40               [100K-150K, 150K+, 50K-100K, <=50K]
#                                                                        >40               [50K-100K, <=50K, 150K+, 100K-150K]
# Name: income, dtype: object

# %%
adults_sub3.groupby(['education', 'marital-status', 'occupation',
       'relationship', 'hours-per-week'])["income"].unique().to_csv("final_grouping.csv")

# %%
adults_sub3.shape
# Out:
# (48842, 7)

# %%
adults_sub3.to_csv("adults_final_4_diversity.csv")

# %%
# As we can see, the table satisfies 4 diversity as there are at least 4 attributeds in each group

# %%
# We have 36 classes of equivalence out of 48 possible
# 48 is theoretical number of classes, but we cannot have combinations like Single + Spouse, 
# So the actual number is lower then 48. Probably close to 36?

# %%
for column in adults_sub3:
  print(adults_sub3[column].unique())
# Out:
# ['HS-Grad or lower' 'Higher Education']
# ['Single' 'Married']
# ['Non-Business Industry' 'Business Industry']
# ['Non-Spouse' 'Spouse']
# ['40' '>40' '<40']
# ['150K+' '50K-100K' '100K-150K' '<=50K']
# [21757 25372 51650 ... 24013 58040 58301]
